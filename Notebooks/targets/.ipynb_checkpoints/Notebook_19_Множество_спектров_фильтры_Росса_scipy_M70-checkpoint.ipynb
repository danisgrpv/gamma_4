# %%
notebook = input('Номер ноутбука: ')
# Out:
# Номер ноутбука: 19

# %%
import sys
import math
import time
sys.path.insert(0, r'/home/danis/work/python_works/gamma_4/Scripts')
sys.path.insert(0, r'D:\Учеба\Практика\Диплом\gamma_4\Scripts')
import numpy as np
import pandas as pd
from materials import*
import matplotlib.pyplot as plt
from garipov_deconvolution import get_coeff_simpson
from garipov_deconvolution import Gold
# Out:
# Минимальная энергия: 1e-3
# windows (w) or linux (l): w

# %%
linspace1 = np.linspace(0.035, 0.1, 25, dtype=np.float32)
linspace2 = np.geomspace(0.11, 3, 25, dtype=np.float32)

beams_energyes = []
beams_energyes.extend(linspace1)
beams_energyes.extend(linspace2)

# %%
m = 70
target = R(Material(m), 0.01)

brems = [target.brem(beams_energy) for beams_energy in beams_energyes]
brems_e = [brem * en for brem in brems]

# %%
fig, ax = plt.subplots(figsize=(9, 7))

for br in brems_e:
    ax.plot(en, br, ls='-', marker='D', lw='0.7', ms=5)

# настройки графика
ax.set_xlabel('Энергия, МэВ', fontsize=10)
ax.set_ylabel('Энергетический спектр, отн. ед', fontsize=10)
ax.tick_params(axis='both', labelsize=10)

ax.set_xscale('log')
# ax.set_yscale('log')
# ax.set_xlim(1e-3, 0.1e0)
# ax.set_ylim(1e-7, 1.2)

ax.grid(True)

# fig.savefig('Тормозной спектр.jpg', bbox_inches='tight')

# %%
n = 11

# %%
# Индексы К скачков
EDGE = []
for i in range(1, len(en)):
    if en[i - 1] == en[i]:
        EDGE.append(i - 1)

# %%
EDGE.remove(EDGE[EDGE.index(Material(m).k_index())])

# %% [markdown]
# Спектральные характеристики чувствительности каналов

# %%
def ross_by_k_level(num_1, num_2, level):
    t_2 = Material(num_2).lt(level)
    f_2 = R(Material(num_2), Material(num_2).lt(level)).f()
    t_1 = Material(num_1).lt(R(Material(num_2), Material(num_2).lt(level)).f()[Material(num_1).k_index()])
    f_1 = R(Material(num_1), t_1).f()
    return f_2 - f_1

# %%
def signals_from_one_spectrum(spectrum, matrix, new_en):
    
    start_time = time.time()
    signals = []
        
    # для каждой строки в матрице
    for row in matrix:
        # значение одного сигнала
        signal = sum(row * np.interp(new_en, en, spectrum))
        signals.append(signal)
        
    return signals

# %%
def func_to_optimize(level, spectrum):
    start_time = time.time()
    resp_ross = [ross_by_k_level(i, i+1, level) for i in range(n, 100)]
    new_en = get_coeff_simpson(resp_ross[0], en, EDGE)[1]
    
    Matrixs = []
    for response in resp_ross:
        Matrixs.append(get_coeff_simpson(response, en, EDGE)[0])
        
    signals_simpson = signals_from_one_spectrum(spectrum, Matrixs, new_en)
    
    sp = [0 for i in range(len(resp_ross))]
    norm = [0 for i in range(len(resp_ross))]
    decb = [0 for i in range(len(resp_ross))]
    dev = [0 for i in range(len(resp_ross))]

    new_en = get_coeff_simpson(resp_ross[0], en, EDGE)[1]
    sp, norm, dev = Gold(Matrixs, signals_simpson, en, spectrum, new_en, 1, 10000, w=True, d=False)[:3]
    print(f'{round((time.time() - start_time), 5)} секунд')
    return dev

# %%
from scipy.optimize import minimize

# %%
deviations = []
optimize_levels = []

init_level = 0.3
counter = 1

for brem in brems_e:
    start = time.time()
    result = minimize(lambda l: func_to_optimize(l, brem), x0=init_level, bounds=([0.05, 0.8],), method='TNC')
    optimize_levels.append(result.x)
    deviations.append(result.fun)
    print(f'ВЫПОЛНЕНО {counter}  из {len(brems_e)}, время: {round(time.time()-start, 6)} секунд')
    counter += 1
# Out:
# 8.65236 секунд
# 8.93743 секунд
# 8.69339 секунд
# 8.80919 секунд
# 9.01528 секунд
# 9.04892 секунд
# ВЫПОЛНЕНО 1  из 50, время: 53.158906 секунд
# 8.94543 секунд
# 8.8557 секунд
# 9.09406 секунд
# 8.98338 секунд
# 8.94566 секунд
# 8.95142 секунд
# 9.05412 секунд
# 9.13733 секунд
# 9.0154 секунд
# 8.87108 секунд
# 8.78969 секунд
# 9.39857 секунд
# 9.24729 секунд
# 9.03721 секунд
# ВЫПОЛНЕНО 2  из 50, время: 126.373237 секунд
# 8.84426 секунд
# 8.91957 секунд
# 9.21993 секунд
# 9.2163 секунд
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <cell line: 7>()
#       7 for brem in brems_e:
#       8     start = time.time()
# ----> 9     result = minimize(lambda l: func_to_optimize(l, brem), x0=init_level, bounds=([0.05, 0.8],), method='TNC')
#      10     optimize_levels.append(result.x)
#      11     deviations.append(result.fun)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_minimize.py:702, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     699     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     700                            callback=callback, **options)
#     701 elif meth == 'tnc':
# --> 702     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     703                         **options)
#     704 elif meth == 'cobyla':
#     705     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     706                             **options)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_tnc.py:424, in _minimize_tnc(fun, x0, args, jac, bounds, eps, scale, offset, mesg_num, maxCGit, maxiter, eta, stepmx, accuracy, minfev, ftol, xtol, gtol, rescale, disp, callback, finite_diff_rel_step, maxfun, **unknown_options)
#     421     else:
#     422         maxfun = max(100, 10*len(x0))
# --> 424 rc, nf, nit, x, funv, jacv = moduleTNC.tnc_minimize(
#     425     func_and_grad, x0, low, up, scale,
#     426     offset, messages, maxCGit, maxfun,
#     427     eta, stepmx, accuracy, fmin, ftol,
#     428     xtol, pgtol, rescale, callback
#     429 )
#     430 # the TNC documentation states: "On output, x, f and g may be very
#     431 # slightly out of sync because of scaling". Therefore re-evaluate
#     432 # func_and_grad so they are synced.
#     433 funv, jacv = func_and_grad(x)
#
# File _moduleTNC.pyx:201, in _moduleTNC.tnc_minimize()
#
# File _moduleTNC.pyx:73, in _moduleTNC.function()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py:285, in ScalarFunction.fun_and_grad(self, x)
#     283 if not np.array_equal(x, self.x):
#     284     self._update_x_impl(x)
# --> 285 self._update_fun()
#     286 self._update_grad()
#     287 return self.f, self.g
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# Input In [20], in <lambda>(l)
#       7 for brem in brems_e:
#       8     start = time.time()
# ----> 9     result = minimize(lambda l: func_to_optimize(l, brem), x0=init_level, bounds=([0.05, 0.8],), method='TNC')
#      10     optimize_levels.append(result.x)
#      11     deviations.append(result.fun)
#
# Input In [18], in func_to_optimize(level, spectrum)
#      15 dev = [0 for i in range(len(resp_ross))]
#      17 new_en = get_coeff_simpson(resp_ross[0], en, EDGE)[1]
# ---> 18 sp, norm, dev = Gold(Matrixs, signals_simpson, en, spectrum, new_en, 1, 10000, w=True, d=False)[:3]
#      19 print(f'{round((time.time() - start_time), 5)} секунд')
#      20 return dev
#
# File D:\Учеба\Практика\Диплом\gamma_4\Scripts\garipov_deconvolution.py:57, in Gold(A, b, en, init_spectrum, dec_en, x0, it, w, d)
#      55 Y = np.dot(A.T, np.dot(W.T, np.dot(W, b)))
#      56 # Создание матрицы AX = A.T * W.T * W * A * x
# ---> 57 AX = np.dot(A.T, np.dot(W.T, np.dot(W, np.dot(A, previous_x))))
#      58 AX[AX == 0] = np.nextafter(0, 1)*1e20
#      59 current_x = 1.0 * previous_x + (previous_x / AX) * (Y - AX)
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
np.save(f'Notebook_{notebook}_DEV_ross_m{m}.npy', deviations)
np.save(f'Notebook_{notebook}_OPTLEV_ross_m{m}.npy', optimize_levels)

# %%
fig, ax = plt.subplots(figsize=(9, 7))

ax.plot(beams_energyes, deviations, ls='-', marker='D', lw='0.7', ms=5, color='blue')

# настройки графика
ax.set_xlabel('Энергия электронов, МэВ', fontsize=10)
ax.set_ylabel('Минимальное среднеквадратичное отклонение по спектру, отн. ед', fontsize=10)
ax.tick_params(axis='both', labelsize=10)
ax.set_xscale('log')
# ax.set_yscale('log')
ax.grid(True)

# fig.savefig('Фильтры_Росса_минимум_ошибки_восстановления_от_энергии_электронов.jpg', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(9, 7))

ax.plot(beams_energyes, optimize_levels, ls='-', marker='D', lw='0.7', ms=5, color='blue')

# настройки графика
ax.set_xlabel('Энергия электронов, МэВ', fontsize=10)
ax.set_ylabel('Оптимальный уровень пропускания в К-крае, отн. ед', fontsize=10)
ax.tick_params(axis='both', labelsize=10)
ax.set_xscale('log')
# ax.set_yscale('log')
ax.grid(True)

# fig.savefig('Фильтры_Росса_минимум_ошибки_восстановления_от_энергии_электронов.jpg', bbox_inches='tight')
