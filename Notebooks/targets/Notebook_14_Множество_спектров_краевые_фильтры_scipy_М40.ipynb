# %%
notebook = input('Номер ноутбука: ')
# Out:
# Номер ноутбука: 14

# %%
import sys
import math
import time
sys.path.insert(0, r'/home/danis/work/python_works/gamma_4/Scripts')
sys.path.insert(0, r'D:\Учеба\Практика\Диплом\gamma_4\Scripts')
import numpy as np
import pandas as pd
from materials import*
import matplotlib.pyplot as plt
from garipov_deconvolution import get_coeff_simpson
from garipov_deconvolution import Gold
# Out:
# Минимальная энергия: 1e-3
# windows (w) or linux (l): l

# %%
linspace1 = np.linspace(0.035, 0.1, 25, dtype=np.float32)
linspace2 = np.geomspace(0.11, 3, 25, dtype=np.float32)

beams_energyes = []
beams_energyes.extend(linspace1)
beams_energyes.extend(linspace2)

# %%
m = 40
target = R(Material(m), 0.01)

brems = [target.brem(beams_energy) for beams_energy in beams_energyes]
brems_e = [brem * en for brem in brems]

# %%
fig, ax = plt.subplots(figsize=(9, 7))

for br in brems_e:
    ax.plot(en, br, ls='-', marker='D', lw='0.7', ms=5)

# настройки графика
ax.set_xlabel('Энергия, МэВ', fontsize=10)
ax.set_ylabel('Энергетический спектр, отн. ед', fontsize=10)
ax.tick_params(axis='both', labelsize=10)

ax.set_xscale('log')
# ax.set_yscale('log')
# ax.set_xlim(1e-3, 0.1e0)
# ax.set_ylim(1e-7, 1.2)

ax.grid(True)

# fig.savefig('Тормозной спектр.jpg', bbox_inches='tight')

# %%
n = 11

# %%
# Индексы К скачков
EDGE = []
for i in range(1, len(en)):
    if en[i - 1] == en[i]:
        EDGE.append(i - 1)

# %%
EDGE.remove(EDGE[EDGE.index(Material(m).k_index())])

# %% [markdown]
# Спектральные характеристики чувствительности каналов

# %%
def signals_from_one_spectrum(spectrum, matrix, new_en):
    
    start_time = time.time()
    signals = []
        
    # для каждой строки в матрице
    for row in matrix:
        # значение одного сигнала
        signal = sum(row * np.interp(new_en, en, spectrum))
        signals.append(signal)
        
    return signals

# %%
def func_to_optimize(level, spectrum):
    start_time = time.time()
    
    edge_thiknesses = [Material(i).lt(level) for i in range(n, 101)]
    edge_regions = [R(Material(i+n), edge_thiknesses[i]) for i in range(0, len(edge_thiknesses))]
    resp_edges = [val.f() for val in edge_regions]
    new_en = get_coeff_simpson(resp_edges[0], en, EDGE)[1]
    
    Matrixs = []
    for response in resp_edges:
        Matrixs.append(get_coeff_simpson(response, en, EDGE)[0])
        
    signals_simpson = signals_from_one_spectrum(spectrum, Matrixs, new_en)
    
    sp = [0 for i in range(len(resp_edges))]
    norm = [0 for i in range(len(resp_edges))]
    decb = [0 for i in range(len(resp_edges))]
    dev = [0 for i in range(len(resp_edges))]

    new_en = get_coeff_simpson(resp_edges[0], en, EDGE)[1]
    sp, norm, dev = Gold(Matrixs, signals_simpson, en, spectrum, new_en, 1, 10000, w=True, d=False)[:3]
    print(f'{round((time.time() - start_time), 5)} секунд')
    return dev

# %%
from scipy.optimize import minimize

# %%
deviations = []
optimize_levels = []

init_level = 0.3
counter = 1

for brem in brems_e:
    start = time.time()
    result = minimize(lambda l: func_to_optimize(l, brem), x0=init_level, bounds=([0.05, 0.8],), method='TNC')
    optimize_levels.append(result.x)
    deviations.append(result.fun)
    print(f'ВЫПОЛНЕНО {counter}  из {len(brems_e)}, время: {round(time.time()-start, 6)} секунд')
    counter += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [18], line 9
#       7 for brem in brems_e:
#       8     start = time.time()
# ----> 9     result = minimize(lambda l: func_to_optimize(l, brem), x0=init_level, bounds=([0.05, 0.8],), method='TNC')
#      10     optimize_levels.append(result.x)
#      11     deviations.append(result.fun)
#
# File ~/work/python_works/gamma_4/env/lib64/python3.10/site-packages/scipy/optimize/_minimize.py:702, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     699     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     700                            callback=callback, **options)
#     701 elif meth == 'tnc':
# --> 702     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     703                         **options)
#     704 elif meth == 'cobyla':
#     705     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     706                             **options)
#
# File ~/work/python_works/gamma_4/env/lib64/python3.10/site-packages/scipy/optimize/_tnc.py:380, in _minimize_tnc(fun, x0, args, jac, bounds, eps, scale, offset, mesg_num, maxCGit, maxiter, eta, stepmx, accuracy, minfev, ftol, xtol, gtol, rescale, disp, callback, finite_diff_rel_step, maxfun, **unknown_options)
#     377 else:
#     378     messages = MSG_NONE
# --> 380 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     381                               finite_diff_rel_step=finite_diff_rel_step,
#     382                               bounds=new_bounds)
#     383 func_and_grad = sf.fun_and_grad
#     385 """
#     386 low, up   : the bounds (lists of floats)
#     387             if low is None, the lower bounds are removed.
#     388             if up is None, the upper bounds are removed.
#     389             low and up defaults to None
#     390 """
#
# File ~/work/python_works/gamma_4/env/lib64/python3.10/site-packages/scipy/optimize/_optimize.py:263, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     259     bounds = (-np.inf, np.inf)
#     261 # ScalarFunction caches. Reuse of fun(x) during grad
#     262 # calculation reduces overall function evaluations.
# --> 263 sf = ScalarFunction(fun, x0, args, grad, hess,
#     264                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     266 return sf
#
# File ~/work/python_works/gamma_4/env/lib64/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:158, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     155     self.f = fun_wrapped(self.x)
#     157 self._update_fun_impl = update_fun
# --> 158 self._update_fun()
#     160 # Gradient evaluation
#     161 if callable(grad):
#
# File ~/work/python_works/gamma_4/env/lib64/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~/work/python_works/gamma_4/env/lib64/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~/work/python_works/gamma_4/env/lib64/python3.10/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# Cell In [18], line 9, in <lambda>(l)
#       7 for brem in brems_e:
#       8     start = time.time()
# ----> 9     result = minimize(lambda l: func_to_optimize(l, brem), x0=init_level, bounds=([0.05, 0.8],), method='TNC')
#      10     optimize_levels.append(result.x)
#      11     deviations.append(result.fun)
#
# Cell In [16], line 13, in func_to_optimize(level, spectrum)
#      10 for response in resp_edges:
#      11     Matrixs.append(get_coeff_simpson(response, en, EDGE)[0])
# ---> 13 signals_simpson = signals_from_one_spectrum(spectrum, Matrixs)
#      15 sp = [0 for i in range(len(resp_edges))]
#      16 norm = [0 for i in range(len(resp_edges))]
#
# Cell In [15], line 9, in signals_from_one_spectrum(spectrum, matrix)
#       6 # для каждой строки в матрице
#       7 for row in matrix:
#       8     # значение одного сигнала
# ----> 9     signal = sum(row * np.interp(new_en, en, spectrum))
#      10     signals.append(signal)
#      12 return signals
#
# NameError: name 'new_en' is not defined

# %%
np.save(f'Notebook_{notebook}_DEV_ross_m{m}.npy', deviations)
np.save(f'Notebook_{notebook}_OPTLEV_ross_m{m}.npy', optimize_levels)

# %%
fig, ax = plt.subplots(figsize=(9, 7))

ax.plot(beams_energyes, deviations, ls='-', marker='D', lw='0.7', ms=5, color='blue')

# настройки графика
ax.set_xlabel('Энергия электронов, МэВ', fontsize=10)
ax.set_ylabel('Минимальное среднеквадратичное отклонение по спектру, отн. ед', fontsize=10)
ax.tick_params(axis='both', labelsize=10)
ax.set_xscale('log')
# ax.set_yscale('log')
ax.grid(True)

# fig.savefig('Фильтры_Росса_минимум_ошибки_восстановления_от_энергии_электронов.jpg', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(9, 7))

ax.plot(beams_energyes, optimize_levels, ls='-', marker='D', lw='0.7', ms=5, color='blue')

# настройки графика
ax.set_xlabel('Энергия электронов, МэВ', fontsize=10)
ax.set_ylabel('Оптимальный уровень пропускания в К-крае, отн. ед', fontsize=10)
ax.tick_params(axis='both', labelsize=10)
ax.set_xscale('log')
# ax.set_yscale('log')
ax.grid(True)

# fig.savefig('Фильтры_Росса_минимум_ошибки_восстановления_от_энергии_электронов.jpg', bbox_inches='tight')
