# %%
import sys
import time
import numpy as np
import numba as nb
from matplotlib import rc
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

# %%
PathWindows = r"D:\Учеба\Практика\Диплом\gamma"
LibraryPathWindows = r"D:\Учеба\Практика\Диплом\gamma\SpectrumsMeasurementsLibrary"
LibraryPathLinux = r"/home/danis/work/python_works/gamma"
sys.path.insert(0, LibraryPathWindows)
sys.path.insert(0, PathWindows)
sys.path.insert(0, LibraryPathLinux)

# %%
from GammaRayInteractions.Materials import Material, R
from CrossSectionsLibrary.cross_sections_data import ENERGY_MESH
from MeasurementInstrumentation.measurement_techniques import ideal_transmission_function, \
k_edge_method_transmission_function, ross_method_transmission_function, edges_indices, open_detector
from NumericalMethods.simpson_rule import simpson_rule
from NumericalMethods.unfolding_technique import Gold

import matplotlib.ticker as mticker
from local_scripts import initialization_brem, generate_empty_matrix, complete_empty_matrix, integrate_the_row, get_integral_signals, apply_function_to_matrix

# %% [markdown]
# Инициализация энергетического спектра

# %%
def log_tick_formatter(val, pos=None):
    return f"$10^{{{int(val)}}}$"

# %%
font_properties = {'family' : 'Arial', 'weight' : 'regular', 'size' : 16}
rc('font', **font_properties)

# %% [markdown]
# Создание энергетических спектров

# %%
linspace1 = np.linspace(0.035, 0.1, 25, dtype=np.float32)
linspace2 = np.geomspace(0.11, 3, 25, dtype=np.float32)

# список энергий пучков электронов
beams_energyes = []
beams_energyes.extend(linspace1)
beams_energyes.extend(linspace2)
beams_energyes = np.array(beams_energyes)

# %%
# зарядовые числа материалов мишеней
z_numbers = np.array([10*i for i in range(1,10)])

# %% [markdown]
# Создание трехмерной матрицы спектров

# %%
# создание матрицы со всеми сгенерированными спектрами
empty_bremsstrahlungs_matrix = generate_empty_matrix(len(z_numbers), len(beams_energyes))
bremsstrahlungs = complete_empty_matrix(empty_bremsstrahlungs_matrix, z_numbers, beams_energyes, initialization_brem)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.plot(ENERGY_MESH, bremsstrahlungs[4][15], ls='-', marker='D', lw='0.7', ms=5, color='orange')

# настройки графика
ax.set_xlabel('Энергия, МэВ')
ax.set_ylabel('Сигнал, отн. ед')
ax.tick_params(axis='both')
# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlim(1e-3, 1e-1)
# ax.set_ylim(1e-15, 1.2)
ax.grid(True)

# %% [markdown]
# Инициализация измерительных каналов

# %%
first_channel = 11
last_channel = 100 
number_of_channels = last_channel - first_channel + 1

# %%
level = 0.1

# %%
# создание измерительных каналов
EDGE_METHOD_channels = [k_edge_method_transmission_function(num, level) for num in range(first_channel, last_channel+1)]
# создание канала с открытым детектором
channel_with_open_detector = open_detector()
# добавление канала с открытым детектором
EDGE_METHOD_channels.insert(0, channel_with_open_detector)

# %%
K = np.array(EDGE_METHOD_channels)

# %%
number_of_signals = fig, ax = plt.subplots(figsize=(10, 10))
for i in EDGE_METHOD_channels:
    ax.plot(ENERGY_MESH, i, ls='-', lw='0.3', ms=5)

# настройки графика
ax.set_xlabel('Энергия, МэВ')
ax.set_ylabel('Сигнал, отн. ед')
ax.tick_params(axis='both')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1e-3, 1e-1)
ax.set_ylim(1e-3, 1.2)
ax.grid(True)

# %% [markdown]
# Создание матрицы с результатами измерения каждого спектра

# %%
empty_integral_signals_matrix = generate_empty_matrix(len(z_numbers), len(beams_energyes))

# %%
SIGNALS = apply_function_to_matrix(bremsstrahlungs, get_integral_signals, K)
# Out:
# Выполнено 1 из 50. Время: 0.4004 секунды
# Выполнено 2 из 50. Время: 0.8121 секунды
# Выполнено 3 из 50. Время: 1.2126 секунды
# Выполнено 4 из 50. Время: 1.6446 секунды
# Выполнено 5 из 50. Время: 2.0461 секунды
# Выполнено 6 из 50. Время: 2.445 секунды
# Выполнено 7 из 50. Время: 2.8453 секунды
# Выполнено 8 из 50. Время: 3.2515 секунды
# Выполнено 9 из 50. Время: 3.6607 секунды
# Выполнено 10 из 50. Время: 4.0749 секунды
# Выполнено 11 из 50. Время: 4.4776 секунды
# Выполнено 12 из 50. Время: 4.8937 секунды
# Выполнено 13 из 50. Время: 5.2797 секунды
# Выполнено 14 из 50. Время: 5.6934 секунды
# Выполнено 15 из 50. Время: 6.1077 секунды
# Выполнено 16 из 50. Время: 6.4962 секунды
# Выполнено 17 из 50. Время: 6.9104 секунды
# Выполнено 18 из 50. Время: 7.3112 секунды
# Выполнено 19 из 50. Время: 7.7384 секунды
# Выполнено 20 из 50. Время: 8.1608 секунды
# Выполнено 21 из 50. Время: 8.5759 секунды
# Выполнено 22 из 50. Время: 8.9841 секунды
# Выполнено 23 из 50. Время: 9.4002 секунды
# Выполнено 24 из 50. Время: 9.8106 секунды
# Выполнено 25 из 50. Время: 10.2222 секунды
# Выполнено 26 из 50. Время: 10.6375 секунды
# Выполнено 27 из 50. Время: 11.0447 секунды
# Выполнено 28 из 50. Время: 11.4465 секунды
# Выполнено 29 из 50. Время: 11.8594 секунды
# Выполнено 30 из 50. Время: 12.2694 секунды
# Выполнено 31 из 50. Время: 12.6615 секунды
# Выполнено 32 из 50. Время: 13.0769 секунды
# Выполнено 33 из 50. Время: 13.478 секунды
# Выполнено 34 из 50. Время: 13.8946 секунды
# Выполнено 35 из 50. Время: 14.2954 секунды
# Выполнено 36 из 50. Время: 14.6953 секунды
# Выполнено 37 из 50. Время: 15.0949 секунды
# Выполнено 38 из 50. Время: 15.5098 секунды
# Выполнено 39 из 50. Время: 15.9107 секунды
# Выполнено 40 из 50. Время: 16.3115 секунды
# Выполнено 41 из 50. Время: 16.7271 секунды
# Выполнено 42 из 50. Время: 17.1277 секунды
# Выполнено 43 из 50. Время: 17.5118 секунды
# Выполнено 44 из 50. Время: 17.9272 секунды
# Выполнено 45 из 50. Время: 18.343 секунды
# Выполнено 46 из 50. Время: 18.7441 секунды
# Выполнено 47 из 50. Время: 19.1279 секунды
# Выполнено 48 из 50. Время: 19.5287 секунды
# Выполнено 49 из 50. Время: 19.9282 секунды
# Выполнено 50 из 50. Время: 20.327 секунды
# ВЫПОЛНЕНО 1 из 9 СТОЛБЦОВ. Время: 20.327 секунды
# Выполнено 1 из 50. Время: 20.7432 секунды
# Выполнено 2 из 50. Время: 21.1444 секунды
# Выполнено 3 из 50. Время: 21.5528 секунды
# Выполнено 4 из 50. Время: 21.9664 секунды
# Выполнено 5 из 50. Время: 22.3749 секунды
# Выполнено 6 из 50. Время: 22.7849 секунды
# Выполнено 7 из 50. Время: 23.2033 секунды
# Выполнено 8 из 50. Время: 23.6066 секунды
# Выполнено 9 из 50. Время: 24.0205 секунды
# Выполнено 10 из 50. Время: 24.4387 секунды
# Выполнено 11 из 50. Время: 24.8461 секунды
# Выполнено 12 из 50. Время: 25.2455 секунды
# Выполнено 13 из 50. Время: 25.6446 секунды
# Выполнено 14 из 50. Время: 26.045 секунды
# Выполнено 15 из 50. Время: 26.4608 секунды
# Выполнено 16 из 50. Время: 26.8778 секунды
# Выполнено 17 из 50. Время: 27.2783 секунды
# Выполнено 18 из 50. Время: 27.68 секунды
# Выполнено 19 из 50. Время: 28.0839 секунды
# Выполнено 20 из 50. Время: 28.4953 секунды
# Выполнено 21 из 50. Время: 28.888 секунды
# Выполнено 22 из 50. Время: 29.2938 секунды
# Выполнено 23 из 50. Время: 29.6946 секунды
# Выполнено 24 из 50. Время: 30.0932 секунды
# Выполнено 25 из 50. Время: 30.4947 секунды
# Выполнено 26 из 50. Время: 30.8949 секунды
# Выполнено 27 из 50. Время: 31.3107 секунды
# Выполнено 28 из 50. Время: 31.712 секунды
# Выполнено 29 из 50. Время: 32.1078 секунды
# Выполнено 30 из 50. Время: 32.5104 секунды
# Выполнено 31 из 50. Время: 32.9119 секунды
# Выполнено 32 из 50. Время: 33.3147 секунды
# Выполнено 33 из 50. Время: 33.7121 секунды
# Выполнено 34 из 50. Время: 34.1234 секунды
# Выполнено 35 из 50. Время: 34.5275 секунды
# Выполнено 36 из 50. Время: 34.9286 секунды
# Выполнено 37 из 50. Время: 35.3286 секунды
# Выполнено 38 из 50. Время: 35.7291 секунды
# Выполнено 39 из 50. Время: 36.1249 секунды
# Выполнено 40 из 50. Время: 36.5427 секунды
# Выполнено 41 из 50. Время: 36.9456 секунды
# Выполнено 42 из 50. Время: 37.3441 секунды
# Выполнено 43 из 50. Время: 37.7448 секунды
# Выполнено 44 из 50. Время: 38.1572 секунды
# Выполнено 45 из 50. Время: 38.5617 секунды
# Выполнено 46 из 50. Время: 38.9619 секунды
# Выполнено 47 из 50. Время: 39.3777 секунды
# Выполнено 48 из 50. Время: 39.7785 секунды
# Выполнено 49 из 50. Время: 40.1743 секунды
# Выполнено 50 из 50. Время: 40.5777 секунды
# ВЫПОЛНЕНО 2 из 9 СТОЛБЦОВ. Время: 40.5777 секунды
# Выполнено 1 из 50. Время: 40.9782 секунды
# Выполнено 2 из 50. Время: 41.3787 секунды
# Выполнено 3 из 50. Время: 41.7931 секунды
# Выполнено 4 из 50. Время: 42.192 секунды
# Выполнено 5 из 50. Время: 42.5938 секунды
# Выполнено 6 из 50. Время: 42.9954 секунды
# Выполнено 7 из 50. Время: 43.3949 секунды
# Выполнено 8 из 50. Время: 43.7954 секунды
# Выполнено 9 из 50. Время: 44.2092 секунды
# Выполнено 10 из 50. Время: 44.6122 секунды
# Выполнено 11 из 50. Время: 45.0115 секунды
# Выполнено 12 из 50. Время: 45.4292 секунды
# Выполнено 13 из 50. Время: 45.8291 секунды
# Выполнено 14 из 50. Время: 46.2294 секунды
# Выполнено 15 из 50. Время: 46.6596 секунды
# Выполнено 16 из 50. Время: 47.0463 секунды
# Выполнено 17 из 50. Время: 47.4456 секунды
# Выполнено 18 из 50. Время: 47.8611 секунды
# Выполнено 19 из 50. Время: 48.2616 секунды
# Выполнено 20 из 50. Время: 48.6794 секунды
# Выполнено 21 из 50. Время: 49.0641 секунды
# Выполнено 22 из 50. Время: 49.4618 секунды
# Выполнено 23 из 50. Время: 49.8622 секунды
# Выполнено 24 из 50. Время: 50.2775 секунды
# Выполнено 25 из 50. Время: 50.6627 секунды
# Выполнено 26 из 50. Время: 51.0786 секунды
# Выполнено 27 из 50. Время: 51.4631 секунды
# Выполнено 28 из 50. Время: 51.8619 секунды
# Выполнено 29 из 50. Время: 52.2783 секунды
# Выполнено 30 из 50. Время: 52.6833 секунды
# Выполнено 31 из 50. Время: 53.0892 секунды
# Выполнено 32 из 50. Время: 53.4982 секунды
# Выполнено 33 из 50. Время: 53.903 секунды
# Выполнено 34 из 50. Время: 54.2964 секунды
# Выполнено 35 из 50. Время: 54.7124 секунды
# Выполнено 36 из 50. Время: 55.1117 секунды
# Выполнено 37 из 50. Время: 55.5125 секунды
# Выполнено 38 из 50. Время: 55.9273 секунды
# Выполнено 39 из 50. Время: 56.3287 секунды
# Выполнено 40 из 50. Время: 56.7291 секунды
# Выполнено 41 из 50. Время: 57.129 секунды
# Выполнено 42 из 50. Время: 57.5284 секунды
# Выполнено 43 из 50. Время: 57.9293 секунды
# Выполнено 44 из 50. Время: 58.3288 секунды
# Выполнено 45 из 50. Время: 58.7292 секунды
# Выполнено 46 из 50. Время: 59.1336 секунды
# Выполнено 47 из 50. Время: 59.5442 секунды
# Выполнено 48 из 50. Время: 59.9485 секунды
# Выполнено 49 из 50. Время: 60.3615 секунды
# Выполнено 50 из 50. Время: 60.7622 секунды
# ВЫПОЛНЕНО 3 из 9 СТОЛБЦОВ. Время: 60.7622 секунды
# Выполнено 1 из 50. Время: 61.1635 секунды
# Выполнено 2 из 50. Время: 61.5774 секунды
# Выполнено 3 из 50. Время: 61.9795 секунды
# Выполнено 4 из 50. Время: 62.3944 секунды
# Выполнено 5 из 50. Время: 62.7953 секунды
# Выполнено 6 из 50. Время: 63.1965 секунды
# Выполнено 7 из 50. Время: 63.5956 секунды
# Выполнено 8 из 50. Время: 63.9969 секунды
# Выполнено 9 из 50. Время: 64.411 секунды
# Выполнено 10 из 50. Время: 64.8126 секунды
# Выполнено 11 из 50. Время: 65.2125 секунды
# Выполнено 12 из 50. Время: 65.6281 секунды
# Выполнено 13 из 50. Время: 66.0284 секунды
# Выполнено 14 из 50. Время: 66.428 секунды
# Выполнено 15 из 50. Время: 66.8287 секунды
# Выполнено 16 из 50. Время: 67.2511 секунды
# Выполнено 17 из 50. Время: 67.6455 секунды
# Выполнено 18 из 50. Время: 68.0601 секунды
# Выполнено 19 из 50. Время: 68.4626 секунды
# Выполнено 20 из 50. Время: 68.8621 секунды
# Выполнено 21 из 50. Время: 69.263 секунды
# Выполнено 22 из 50. Время: 69.6777 секунды
# Выполнено 23 из 50. Время: 70.0786 секунды
# Выполнено 24 из 50. Время: 70.4944 секунды
# Выполнено 25 из 50. Время: 70.8957 секунды
# Выполнено 26 из 50. Время: 71.2955 секунды
# Выполнено 27 из 50. Время: 71.7112 секунды
# Выполнено 28 из 50. Время: 72.1125 секунды
# Выполнено 29 из 50. Время: 72.5119 секунды
# Выполнено 30 из 50. Время: 72.9126 секунды
# Выполнено 31 из 50. Время: 73.3155 секунды
# Выполнено 32 из 50. Время: 73.7124 секунды
# Выполнено 33 из 50. Время: 74.1123 секунды
# Выполнено 34 из 50. Время: 74.53 секунды
# Выполнено 35 из 50. Время: 74.929 секунды
# Выполнено 36 из 50. Время: 75.3294 секунды
# Выполнено 37 из 50. Время: 75.7136 секунды
# Выполнено 38 из 50. Время: 76.1123 секунды
# Выполнено 39 из 50. Время: 76.5284 секунды
# Выполнено 40 из 50. Время: 76.9292 секунды
# Выполнено 41 из 50. Время: 77.3296 секунды
# Выполнено 42 из 50. Время: 77.7451 секунды
# Выполнено 43 из 50. Время: 78.1452 секунды
# Выполнено 44 из 50. Время: 78.5454 секунды
# Выполнено 45 из 50. Время: 78.9451 секунды
# Выполнено 46 из 50. Время: 79.3451 секунды
# Выполнено 47 из 50. Время: 79.7449 секунды
# Выполнено 48 из 50. Время: 80.1624 секунды
# Выполнено 49 из 50. Время: 80.5625 секунды
# Выполнено 50 из 50. Время: 80.9612 секунды
# ВЫПОЛНЕНО 4 из 9 СТОЛБЦОВ. Время: 80.9612 секунды
# Выполнено 1 из 50. Время: 81.3623 секунды
# Выполнено 2 из 50. Время: 81.7628 секунды
# Выполнено 3 из 50. Время: 82.1862 секунды
# Выполнено 4 из 50. Время: 82.5791 секунды
# Выполнено 5 из 50. Время: 82.9955 секунды
# Выполнено 6 из 50. Время: 83.3827 секунды
# Выполнено 7 из 50. Время: 83.795 секунды
# Выполнено 8 из 50. Время: 84.2066 секунды
# Выполнено 9 из 50. Время: 84.6111 секунды
# Выполнено 10 из 50. Время: 85.0113 секунды
# Выполнено 11 из 50. Время: 85.412 секунды
# Выполнено 12 из 50. Время: 85.8274 секунды
# Выполнено 13 из 50. Время: 86.2396 секунды
# Выполнено 14 из 50. Время: 86.6446 секунды
# Выполнено 15 из 50. Время: 87.045 секунды
# Выполнено 16 из 50. Время: 87.4453 секунды
# Выполнено 17 из 50. Время: 87.8772 секунды
# Выполнено 18 из 50. Время: 88.2746 секунды
# Выполнено 19 из 50. Время: 88.6786 секунды
# Выполнено 20 из 50. Время: 89.0789 секунды
# Выполнено 21 из 50. Время: 89.481 секунды
# Выполнено 22 из 50. Время: 89.8945 секунды
# Выполнено 23 из 50. Время: 90.2916 секунды
# Выполнено 24 из 50. Время: 90.6946 секунды
# Выполнено 25 из 50. Время: 91.0954 секунды
# Выполнено 26 из 50. Время: 91.4964 секунды
# Выполнено 27 из 50. Время: 91.8946 секунды
# Выполнено 28 из 50. Время: 92.3093 секунды
# Выполнено 29 из 50. Время: 92.7115 секунды
# Выполнено 30 из 50. Время: 93.1128 секунды
# Выполнено 31 из 50. Время: 93.5293 секунды
# Выполнено 32 из 50. Время: 93.9399 секунды
# Выполнено 33 из 50. Время: 94.3492 секунды
# Выполнено 34 из 50. Время: 94.7622 секунды
# Выполнено 35 из 50. Время: 95.1617 секунды
# Выполнено 36 из 50. Время: 95.5628 секунды
# Выполнено 37 из 50. Время: 95.9785 секунды
# Выполнено 38 из 50. Время: 96.3654 секунды
# Выполнено 39 из 50. Время: 96.763 секунды
# Выполнено 40 из 50. Время: 97.1628 секунды
# Выполнено 41 из 50. Время: 97.5783 секунды
# Выполнено 42 из 50. Время: 97.9626 секунды
# Выполнено 43 из 50. Время: 98.3854 секунды
# Выполнено 44 из 50. Время: 98.7952 секунды
# Выполнено 45 из 50. Время: 99.1946 секунды
# Выполнено 46 из 50. Время: 99.5957 секунды
# Выполнено 47 из 50. Время: 99.9961 секунды
# Выполнено 48 из 50. Время: 100.3959 секунды
# Выполнено 49 из 50. Время: 100.812 секунды
# Выполнено 50 из 50. Время: 101.2118 секунды
# ВЫПОЛНЕНО 5 из 9 СТОЛБЦОВ. Время: 101.2118 секунды
# Выполнено 1 из 50. Время: 101.6125 секунды
# Выполнено 2 из 50. Время: 102.0321 секунды
# Выполнено 3 из 50. Время: 102.449 секунды
# Выполнено 4 из 50. Время: 102.8685 секунды
# Выполнено 5 из 50. Время: 103.2718 секунды
# Выполнено 6 из 50. Время: 103.6783 секунды
# Выполнено 7 из 50. Время: 104.0644 секунды
# Выполнено 8 из 50. Время: 104.4633 секунды
# Выполнено 9 из 50. Время: 104.874 секунды
# Выполнено 10 из 50. Время: 105.2779 секунды
# Выполнено 11 из 50. Время: 105.6797 секунды
# Выполнено 12 из 50. Время: 106.0795 секунды
# Выполнено 13 из 50. Время: 106.4948 секунды
# Выполнено 14 из 50. Время: 106.8966 секунды
# Выполнено 15 из 50. Время: 107.2803 секунды
# Выполнено 16 из 50. Время: 107.6946 секунды
# Выполнено 17 из 50. Время: 108.0809 секунды
# Выполнено 18 из 50. Время: 108.4965 секунды
# Выполнено 19 из 50. Время: 108.8958 секунды
# Выполнено 20 из 50. Время: 109.2803 секунды
# Выполнено 21 из 50. Время: 109.6793 секунды
# Выполнено 22 из 50. Время: 110.0795 секунды
# Выполнено 23 из 50. Время: 110.4957 секунды
# Выполнено 24 из 50. Время: 110.8807 секунды
# Выполнено 25 из 50. Время: 111.2794 секунды
# Выполнено 26 из 50. Время: 111.68 секунды
# Выполнено 27 из 50. Время: 112.0948 секунды
# Выполнено 28 из 50. Время: 112.4966 секунды
# Выполнено 29 из 50. Время: 112.896 секунды
# Выполнено 30 из 50. Время: 113.2965 секунды
# Выполнено 31 из 50. Время: 113.7129 секунды
# Выполнено 32 из 50. Время: 114.1134 секунды
# Выполнено 33 из 50. Время: 114.5126 секунды
# Выполнено 34 из 50. Время: 114.9133 секунды
# Выполнено 35 из 50. Время: 115.3129 секунды
# Выполнено 36 из 50. Время: 115.7142 секунды
# Выполнено 37 из 50. Время: 116.1134 секунды
# Выполнено 38 из 50. Время: 116.5143 секунды
# Выполнено 39 из 50. Время: 116.9284 секунды
# Выполнено 40 из 50. Время: 117.3141 секунды
# Выполнено 41 из 50. Время: 117.714 секунды
# Выполнено 42 из 50. Время: 118.1287 секунды
# Выполнено 43 из 50. Время: 118.5298 секунды
# Выполнено 44 из 50. Время: 118.9293 секунды
# Выполнено 45 из 50. Время: 119.3458 секунды
# Выполнено 46 из 50. Время: 119.7308 секунды
# Выполнено 47 из 50. Время: 120.1473 секунды
# Выполнено 48 из 50. Время: 120.5625 секунды
# Выполнено 49 из 50. Время: 120.9626 секунды
# Выполнено 50 из 50. Время: 121.3632 секунды
# ВЫПОЛНЕНО 6 из 9 СТОЛБЦОВ. Время: 121.3632 секунды
# Выполнено 1 из 50. Время: 121.7641 секунды
# Выполнено 2 из 50. Время: 122.1636 секунды
# Выполнено 3 из 50. Время: 122.5633 секунды
# Выполнено 4 из 50. Время: 122.9628 секунды
# Выполнено 5 из 50. Время: 123.366 секунды
# Выполнено 6 из 50. Время: 123.7642 секунды
# Выполнено 7 из 50. Время: 124.179 секунды
# Выполнено 8 из 50. Время: 124.5799 секунды
# Выполнено 9 из 50. Время: 124.9644 секунды
# Выполнено 10 из 50. Время: 125.3791 секунды
# Выполнено 11 из 50. Время: 125.7667 секунды
# Выполнено 12 из 50. Время: 126.179 секунды
# Выполнено 13 из 50. Время: 126.5794 секунды
# Выполнено 14 из 50. Время: 126.9773 секунды
# Выполнено 15 из 50. Время: 127.3804 секунды
# Выполнено 16 из 50. Время: 127.795 секунды
# Выполнено 17 из 50. Время: 128.1957 секунды
# Выполнено 18 из 50. Время: 128.5964 секунды
# Выполнено 19 из 50. Время: 129.0124 секунды
# Выполнено 20 из 50. Время: 129.4134 секунды
# Выполнено 21 из 50. Время: 129.816 секунды
# Выполнено 22 из 50. Время: 130.2242 секунды
# Выполнено 23 из 50. Время: 130.6454 секунды
# Выполнено 24 из 50. Время: 131.0467 секунды
# Выполнено 25 из 50. Время: 131.4467 секунды
# Выполнено 26 из 50. Время: 131.8469 секунды
# Выполнено 27 из 50. Время: 132.2678 секунды
# Выполнено 28 из 50. Время: 132.6707 секунды
# Выполнено 29 из 50. Время: 133.1061 секунды
# Выполнено 30 из 50. Время: 133.5061 секунды
# Выполнено 31 из 50. Время: 133.9158 секунды
# Выполнено 32 из 50. Время: 134.349 секунды
# Выполнено 33 из 50. Время: 134.7618 секунды
# Выполнено 34 из 50. Время: 135.1701 секунды
# Выполнено 35 из 50. Время: 135.5881 секунды
# Выполнено 36 из 50. Время: 135.9965 секунды
# Выполнено 37 из 50. Время: 136.409 секунды
# Выполнено 38 из 50. Время: 136.8264 секунды
# Выполнено 39 из 50. Время: 137.2352 секунды
# Выполнено 40 из 50. Время: 137.6578 секунды
# Выполнено 41 из 50. Время: 138.0636 секунды
# Выполнено 42 из 50. Время: 138.4614 секунды
# Выполнено 43 из 50. Время: 138.8629 секунды
# Выполнено 44 из 50. Время: 139.2787 секунды
# Выполнено 45 из 50. Время: 139.6802 секунды
# Выполнено 46 из 50. Время: 140.0956 секунды
# Выполнено 47 из 50. Время: 140.4926 секунды
# Выполнено 48 из 50. Время: 140.8962 секунды
# Выполнено 49 из 50. Время: 141.2969 секунды
# Выполнено 50 из 50. Время: 141.6964 секунды
# ВЫПОЛНЕНО 7 из 9 СТОЛБЦОВ. Время: 141.6964 секунды
# Выполнено 1 из 50. Время: 142.0965 секунды
# Выполнено 2 из 50. Время: 142.4925 секунды
# Выполнено 3 из 50. Время: 142.8804 секунды
# Выполнено 4 из 50. Время: 143.2799 секунды
# Выполнено 5 из 50. Время: 143.6802 секунды
# Выполнено 6 из 50. Время: 144.0797 секунды
# Выполнено 7 из 50. Время: 144.4759 секунды
# Выполнено 8 из 50. Время: 144.8803 секунды
# Выполнено 9 из 50. Время: 145.2805 секунды
# Выполнено 10 из 50. Время: 145.68 секунды
# Выполнено 11 из 50. Время: 146.0957 секунды
# Выполнено 12 из 50. Время: 146.4941 секунды
# Выполнено 13 из 50. Время: 146.9135 секунды
# Выполнено 14 из 50. Время: 147.3319 секунды
# Выполнено 15 из 50. Время: 147.7462 секунды
# Выполнено 16 из 50. Время: 148.1463 секунды
# Выполнено 17 из 50. Время: 148.5597 секунды
# Выполнено 18 из 50. Время: 148.9638 секунды
# Выполнено 19 из 50. Время: 149.3636 секунды
# Выполнено 20 из 50. Время: 149.7634 секунды
# Выполнено 21 из 50. Время: 150.1799 секунды
# Выполнено 22 из 50. Время: 150.5762 секунды
# Выполнено 23 из 50. Время: 150.9798 секунды
# Выполнено 24 из 50. Время: 151.3804 секунды
# Выполнено 25 из 50. Время: 151.7799 секунды
# Выполнено 26 из 50. Время: 152.1961 секунды
# Выполнено 27 из 50. Время: 152.6041 секунды
# Выполнено 28 из 50. Время: 152.9986 секунды
# Выполнено 29 из 50. Время: 153.3993 секунды
# Выполнено 30 из 50. Время: 153.7971 секунды
# Выполнено 31 из 50. Время: 154.2133 секунды
# Выполнено 32 из 50. Время: 154.6247 секунды
# Выполнено 33 из 50. Время: 155.0416 секунды
# Выполнено 34 из 50. Время: 155.4378 секунды
# Выполнено 35 из 50. Время: 155.8296 секунды
# Выполнено 36 из 50. Время: 156.238 секунды
# Выполнено 37 из 50. Время: 156.6488 секунды
# Выполнено 38 из 50. Время: 157.0629 секунды
# Выполнено 39 из 50. Время: 157.4626 секунды
# Выполнено 40 из 50. Время: 157.8789 секунды
# Выполнено 41 из 50. Время: 158.2634 секунды
# Выполнено 42 из 50. Время: 158.6794 секунды
# Выполнено 43 из 50. Время: 159.0797 секунды
# Выполнено 44 из 50. Время: 159.4793 секунды
# Выполнено 45 из 50. Время: 159.8867 секунды
# Выполнено 46 из 50. Время: 160.2958 секунды
# Выполнено 47 из 50. Время: 160.6973 секунды
# Выполнено 48 из 50. Время: 161.098 секунды
# Выполнено 49 из 50. Время: 161.5171 секунды
# Выполнено 50 из 50. Время: 161.9224 секунды
# ВЫПОЛНЕНО 8 из 9 СТОЛБЦОВ. Время: 161.9224 секунды
# Выполнено 1 из 50. Время: 162.3135 секунды
# Выполнено 2 из 50. Время: 162.7292 секунды
# Выполнено 3 из 50. Время: 163.1297 секунды
# Выполнено 4 из 50. Время: 163.5308 секунды
# Выполнено 5 из 50. Время: 163.9302 секунды
# Выполнено 6 из 50. Время: 164.3308 секунды
# Выполнено 7 из 50. Время: 164.7467 секунды
# Выполнено 8 из 50. Время: 165.1469 секунды
# Выполнено 9 из 50. Время: 165.5472 секунды
# Выполнено 10 из 50. Время: 165.9474 секунды
# Выполнено 11 из 50. Время: 166.3622 секунды
# Выполнено 12 из 50. Время: 166.7631 секунды
# Выполнено 13 из 50. Время: 167.1635 секунды
# Выполнено 14 из 50. Время: 167.5775 секунды
# Выполнено 15 из 50. Время: 167.979 секунды
# Выполнено 16 из 50. Время: 168.3802 секунды
# Выполнено 17 из 50. Время: 168.7794 секунды
# Выполнено 18 из 50. Время: 169.18 секунды
# Выполнено 19 из 50. Время: 169.5807 секунды
# Выполнено 20 из 50. Время: 169.9801 секунды
# Выполнено 21 из 50. Время: 170.3802 секунды
# Выполнено 22 из 50. Время: 170.7809 секунды
# Выполнено 23 из 50. Время: 171.1814 секунды
# Выполнено 24 из 50. Время: 171.5799 секунды
# Выполнено 25 из 50. Время: 171.9958 секунды
# Выполнено 26 из 50. Время: 172.3963 секунды
# Выполнено 27 из 50. Время: 172.7966 секунды
# Выполнено 28 из 50. Время: 173.1981 секунды
# Выполнено 29 из 50. Время: 173.5976 секунды
# Выполнено 30 из 50. Время: 174.0128 секунды
# Выполнено 31 из 50. Время: 174.4137 секунды
# Выполнено 32 из 50. Время: 174.8137 секунды
# Выполнено 33 из 50. Время: 175.2297 секунды
# Выполнено 34 из 50. Время: 175.6301 секунды
# Выполнено 35 из 50. Время: 176.0496 секунды
# Выполнено 36 из 50. Время: 176.4615 секунды
# Выполнено 37 из 50. Время: 176.8758 секунды
# Выполнено 38 из 50. Время: 177.2868 секунды
# Выполнено 39 из 50. Время: 177.682 секунды
# Выполнено 40 из 50. Время: 178.0961 секунды
# Выполнено 41 из 50. Время: 178.5111 секунды
# Выполнено 42 из 50. Время: 178.925 секунды
# Выполнено 43 из 50. Время: 179.3314 секунды
# Выполнено 44 из 50. Время: 179.7379 секунды
# Выполнено 45 из 50. Время: 180.147 секунды
# Выполнено 46 из 50. Время: 180.555 секунды
# Выполнено 47 из 50. Время: 181.0065 секунды
# Выполнено 48 из 50. Время: 181.4125 секунды
# Выполнено 49 из 50. Время: 181.8212 секунды
# Выполнено 50 из 50. Время: 182.2301 секунды
# ВЫПОЛНЕНО 9 из 9 СТОЛБЦОВ. Время: 182.2301 секунды

# %%
# вычисление среднего значение энергии в полосах пропускания измерительных каналов
left_bounds = [Material(i).k_edge_energy() for i in range(11, 100)]
right_bounds = [val for val in left_bounds]
mean_energy_in_pass_band = (np.array(right_bounds) + np.array(left_bounds)) / 2

# %%
number_of_signals = len(EDGE_METHOD_channels)
fig, ax = plt.subplots(figsize=(10, 10))

ax.plot(range(number_of_signals), SIGNALS[1][20], ls='-', marker='D', lw='0.7', ms=5, color='orange')

# настройки графика
ax.set_xlabel('Энергия, МэВ')
ax.set_ylabel('Сигнал, отн. ед')
ax.tick_params(axis='both')
# ax.set_xscale('log')
# ax.set_yscale('log')
# ax.set_xlim(1e-3, 1e+2)
# ax.set_ylim(1e-15, 1.2)
ax.grid(True)

# %% [markdown]
# Динамический диапазон

# %%
axis1_energy, axis_z = np.meshgrid(beams_energyes, z_numbers)

# %%
axis_channels, axis2_energy = np.meshgrid([i for i in range(first_channel, last_channel+2)], beams_energyes)

# %%
SIGNALS.shape
# Out:
# (9, 50, 91)

# %%
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': '3d'})
ax.plot_surface(axis2_energy[:30], axis_channels[:30], SIGNALS[4,:30,:], cmap=cm.Set2, linewidth=0.3, edgecolors='k', shade=True)

ax.set_xlabel('Энергия электронов, МэВ')
ax.set_ylabel('Номер канала')
# ax.set_zlabel('Ср.кв. ошибка восстановления, отн. ед.')
fig.tight_layout()

# ax.xaxis.set_major_formatter(mticker.FuncFormatter(log_tick_formatter))
# ax.xaxis.set_major_locator(mticker.MaxNLocator(integer=True))

# угол зрения (линейный)
# ax.view_init(elev=20, azim=-135)



# угол зрения (логарифм)
ax.view_init(elev=30, azim=45)
# fig.tight_layout()
# fig.savefig(f'ФК {}.jpg', bbox_inches='tight')

# %% [markdown]
# Восстановление спектра

# %%
# создание матрицы задачи
Matrix = np.array([simpson_rule(r, regime='c', function_jumps=[Material(60).k_edge_index()]) for r in EDGE_METHOD_channels])
new_mesh = np.array(simpson_rule(EDGE_METHOD_channels[0], regime='m', function_jumps=[Material(60).k_edge_index()]))

# %%
z_example = 5
en_example = 15

# %%
signals_simpson = SIGNALS[z_example][en_example]
brem = bremsstrahlungs[z_example][en_example]
bound_100_kev = Material(100).k_edge_index()

# %%
result = Gold(Matrix, signals_simpson, 2, ENERGY_MESH, new_mesh, brem, iteration_number=10000, bound=bound_100_kev, journal=False, weight_mode='channel')

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.plot(ENERGY_MESH, brem, ls='-', lw='2', ms=5, color='magenta')
ax.plot(new_mesh, result[0], ls='-', lw='2', ms=5, color='blue')


# настройки графика
ax.set_xlabel('Энергия, МэВ', fontsize=12)
ax.set_ylabel('Энергетический спектр, отн. ед', fontsize=12)
ax.tick_params(axis='both', labelsize=12)
# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlim(1e-3, 0.1e0)
# ax.set_ylim(1e-7, 1.2)
ax.grid(True)

# %% [markdown]
# #

# %% [markdown]
# Сохранение результатов

# %%
K_EDGE_METHOD_SIGNALS = np.save('СИГНАЛЫ_К_пропускание_08.npy', SIGNALS)
