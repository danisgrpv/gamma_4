# %%
import sys
import time
import numpy as np
import numba as nb
from matplotlib import rc
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

# %%
PathWindows = r"D:\Учеба\Практика\Диплом\gamma"
LibraryPathWindows = r"D:\Учеба\Практика\Диплом\gamma\SpectrumsMeasurementsLibrary"
LibraryPathLinux = r"/home/danis/work/python_works/gamma"
sys.path.insert(0, LibraryPathWindows)
sys.path.insert(0, PathWindows)
sys.path.insert(0, LibraryPathLinux)

# %%
from GammaRayInteractions.Materials import Material, R
from CrossSectionsLibrary.cross_sections_data import ENERGY_MESH
from MeasurementInstrumentation.measurement_techniques import ideal_transmission_function, \
k_edge_method_transmission_function, ross_method_transmission_function, edges_indices, open_detector
from NumericalMethods.simpson_rule import simpson_rule
from NumericalMethods.unfolding_technique import Gold

import matplotlib.ticker as mticker
from local_scripts import initialization_brem, generate_empty_matrix, complete_empty_matrix, integrate_the_row, get_integral_signals, apply_function_to_matrix

# %%
def log_tick_formatter(val, pos=None):
    return f"$10^{{{int(val)}}}$"

# %%
font_properties = {'family' : 'Arial', 'weight' : 'regular', 'size' : 12}
rc('font', **font_properties)

# %% [markdown]
# Создание энергетических спектров

# %%
linspace1 = np.linspace(0.035, 0.1, 25, dtype=np.float32)
linspace2 = np.geomspace(0.11, 3, 25, dtype=np.float32)

# список энергий пучков электронов
beams_energyes = []
beams_energyes.extend(linspace1)
beams_energyes.extend(linspace2)
beams_energyes = np.array(beams_energyes)

# %%
# зарядовые числа материалов мишеней
z_numbers = np.array([10*i for i in range(1,10)])

# %% [markdown]
# Создание трехмерной матрицы спектров

# %%
# создание матрицы со всеми сгенерированными спектрами
empty_bremsstrahlungs_matrix = generate_empty_matrix(len(z_numbers), len(beams_energyes))
bremsstrahlungs = complete_empty_matrix(empty_bremsstrahlungs_matrix, z_numbers, beams_energyes, initialization_brem)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.plot(ENERGY_MESH, bremsstrahlungs[4][15], ls='-', marker='D', lw='0.7', ms=5, color='orange')

# настройки графика
ax.set_xlabel('Энергия, МэВ')
ax.set_ylabel('Сигнал, отн. ед')
ax.tick_params(axis='both')
# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlim(1e-3, 1e-1)
# ax.set_ylim(1e-15, 1.2)
ax.grid(True)

# %% [markdown]
# Инициализация измерительных каналов

# %%
first_channel = 11
last_channel = 100 
number_of_channels = last_channel - first_channel + 1

# %%
level = 0.4

# %%
# создание измерительных каналов
EDGE_METHOD_channels = [k_edge_method_transmission_function(num, level) for num in range(first_channel, last_channel+1)]
# создание канала с открытым детектором
channel_with_open_detector = open_detector()
# добавление канала с открытым детектором
EDGE_METHOD_channels.insert(0, channel_with_open_detector)

# %%
K = np.array(EDGE_METHOD_channels)

# %%
number_of_signals = fig, ax = plt.subplots(figsize=(10, 10))
for i in EDGE_METHOD_channels:
    ax.plot(ENERGY_MESH, i, ls='-', lw='0.3', ms=5)

# настройки графика
ax.set_xlabel('Энергия, МэВ')
ax.set_ylabel('Сигнал, отн. ед')
ax.tick_params(axis='both')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1e-3, 1e-1)
ax.set_ylim(1e-3, 1.2)
ax.grid(True)

# %% [markdown]
# Создание матрицы с результатами измерения каждого спектра

# %%
empty_integral_signals_matrix = generate_empty_matrix(len(z_numbers), len(beams_energyes))

# %%
SIGNALS = apply_function_to_matrix(bremsstrahlungs, get_integral_signals, K)
# Out:
# Выполнено 1 из 50. Время: 0.402 секунды
# Выполнено 2 из 50. Время: 0.7976 секунды
# Выполнено 3 из 50. Время: 1.2296 секунды
# Выполнено 4 из 50. Время: 1.6505 секунды
# Выполнено 5 из 50. Время: 2.0739 секунды
# Выполнено 6 из 50. Время: 2.4977 секунды
# Выполнено 7 из 50. Время: 2.9063 секунды
# Выполнено 8 из 50. Время: 3.3145 секунды
# Выполнено 9 из 50. Время: 3.721 секунды
# Выполнено 10 из 50. Время: 4.1298 секунды
# Выполнено 11 из 50. Время: 4.5473 секунды
# Выполнено 12 из 50. Время: 4.9614 секунды
# Выполнено 13 из 50. Время: 5.3655 секунды
# Выполнено 14 из 50. Время: 5.7742 секунды
# Выполнено 15 из 50. Время: 6.1825 секунды
# Выполнено 16 из 50. Время: 6.5976 секунды
# Выполнено 17 из 50. Время: 7.009 секунды
# Выполнено 18 из 50. Время: 7.4193 секунды
# Выполнено 19 из 50. Время: 7.8304 секунды
# Выполнено 20 из 50. Время: 8.2312 секунды
# Выполнено 21 из 50. Время: 8.6484 секунды
# Выполнено 22 из 50. Время: 9.0664 секунды
# Выполнено 23 из 50. Время: 9.473 секунды
# Выполнено 24 из 50. Время: 9.8645 секунды
# Выполнено 25 из 50. Время: 10.2798 секунды
# Выполнено 26 из 50. Время: 10.6869 секунды
# Выполнено 27 из 50. Время: 11.1052 секунды
# Выполнено 28 из 50. Время: 11.4978 секунды
# Выполнено 29 из 50. Время: 11.9132 секунды
# Выполнено 30 из 50. Время: 12.3134 секунды
# Выполнено 31 из 50. Время: 12.7205 секунды
# Выполнено 32 из 50. Время: 13.1298 секунды
# Выполнено 33 из 50. Время: 13.5295 секунды
# Выполнено 34 из 50. Время: 13.9472 секунды
# Выполнено 35 из 50. Время: 14.336 секунды
# Выполнено 36 из 50. Время: 14.7564 секунды
# Выполнено 37 из 50. Время: 15.1677 секунды
# Выполнено 38 из 50. Время: 15.564 секунды
# Выполнено 39 из 50. Время: 15.9806 секунды
# Выполнено 40 из 50. Время: 16.3893 секунды
# Выполнено 41 из 50. Время: 16.7964 секунды
# Выполнено 42 из 50. Время: 17.1973 секунды
# Выполнено 43 из 50. Время: 17.6133 секунды
# Выполнено 44 из 50. Время: 18.021 секунды
# Выполнено 45 из 50. Время: 18.4143 секунды
# Выполнено 46 из 50. Время: 18.83 секунды
# Выполнено 47 из 50. Время: 19.2311 секунды
# Выполнено 48 из 50. Время: 19.6524 секунды
# Выполнено 49 из 50. Время: 20.0597 секунды
# Выполнено 50 из 50. Время: 20.4638 секунды
# ВЫПОЛНЕНО 1 из 9 СТОЛБЦОВ. Время: 20.4638 секунды
# Выполнено 1 из 50. Время: 20.8797 секунды
# Выполнено 2 из 50. Время: 21.2829 секунды
# Выполнено 3 из 50. Время: 21.689 секунды
# Выполнено 4 из 50. Время: 22.097 секунды
# Выполнено 5 из 50. Время: 22.4973 секунды
# Выполнено 6 из 50. Время: 22.8982 секунды
# Выполнено 7 из 50. Время: 23.3032 секунды
# Выполнено 8 из 50. Время: 23.7302 секунды
# Выполнено 9 из 50. Время: 24.1314 секунды
# Выполнено 10 из 50. Время: 24.5444 секунды
# Выполнено 11 из 50. Время: 24.9518 секунды
# Выполнено 12 из 50. Время: 25.3634 секунды
# Выполнено 13 из 50. Время: 25.7655 секунды
# Выполнено 14 из 50. Время: 26.1643 секунды
# Выполнено 15 из 50. Время: 26.5653 секунды
# Выполнено 16 из 50. Время: 26.9736 секунды
# Выполнено 17 из 50. Время: 27.3807 секунды
# Выполнено 18 из 50. Время: 27.797 секунды
# Выполнено 19 из 50. Время: 28.198 секунды
# Выполнено 20 из 50. Время: 28.6192 секунды
# Выполнено 21 из 50. Время: 29.0264 секунды
# Выполнено 22 из 50. Время: 29.4313 секунды
# Выполнено 23 из 50. Время: 29.8322 секунды
# Выполнено 24 из 50. Время: 30.2357 секунды
# Выполнено 25 из 50. Время: 30.6471 секунды
# Выполнено 26 из 50. Время: 31.0623 секунды
# Выполнено 27 из 50. Время: 31.4752 секунды
# Выполнено 28 из 50. Время: 31.8826 секунды
# Выполнено 29 из 50. Время: 32.2895 секунды
# Выполнено 30 из 50. Время: 32.7134 секунды
# Выполнено 31 из 50. Время: 33.1118 секунды
# Выполнено 32 из 50. Время: 33.5379 секунды
# Выполнено 33 из 50. Время: 33.9365 секунды
# Выполнено 34 из 50. Время: 34.3524 секунды
# Выполнено 35 из 50. Время: 34.7478 секунды
# Выполнено 36 из 50. Время: 35.163 секунды
# Выполнено 37 из 50. Время: 35.5675 секунды
# Выполнено 38 из 50. Время: 35.9794 секунды
# Выполнено 39 из 50. Время: 36.3811 секунды
# Выполнено 40 из 50. Время: 36.7819 секунды
# Выполнено 41 из 50. Время: 37.1851 секунды
# Выполнено 42 из 50. Время: 37.5895 секунды
# Выполнено 43 из 50. Время: 37.9963 секунды
# Выполнено 44 из 50. Время: 38.4137 секунды
# Выполнено 45 из 50. Время: 38.8144 секунды
# Выполнено 46 из 50. Время: 39.2365 секунды
# Выполнено 47 из 50. Время: 39.6309 секунды
# Выполнено 48 из 50. Время: 40.0452 секунды
# Выполнено 49 из 50. Время: 40.4473 секунды
# Выполнено 50 из 50. Время: 40.8531 секунды
# ВЫПОЛНЕНО 2 из 9 СТОЛБЦОВ. Время: 40.8531 секунды
# Выполнено 1 из 50. Время: 41.264 секунды
# Выполнено 2 из 50. Время: 41.6803 секунды
# Выполнено 3 из 50. Время: 42.0813 секунды
# Выполнено 4 из 50. Время: 42.4819 секунды
# Выполнено 5 из 50. Время: 42.8895 секунды
# Выполнено 6 из 50. Время: 43.2968 секунды
# Выполнено 7 из 50. Время: 43.6982 секунды
# Выполнено 8 из 50. Время: 44.0988 секунды
# Выполнено 9 из 50. Время: 44.5191 секунды
# Выполнено 10 из 50. Время: 44.9303 секунды
# Выполнено 11 из 50. Время: 45.3314 секунды
# Выполнено 12 из 50. Время: 45.7319 секунды
# Выполнено 13 из 50. Время: 46.1358 секунды
# Выполнено 14 из 50. Время: 46.5493 секунды
# Выполнено 15 из 50. Время: 46.9484 секунды
# Выполнено 16 из 50. Время: 47.3481 секунды
# Выполнено 17 из 50. Время: 47.7662 секунды
# Выполнено 18 из 50. Время: 48.1735 секунды
# Выполнено 19 из 50. Время: 48.5642 секунды
# Выполнено 20 из 50. Время: 48.9806 секунды
# Выполнено 21 из 50. Время: 49.3828 секунды
# Выполнено 22 из 50. Время: 49.7886 секунды
# Выполнено 23 из 50. Время: 50.1811 секунды
# Выполнено 24 из 50. Время: 50.597 секунды
# Выполнено 25 из 50. Время: 50.998 секунды
# Выполнено 26 из 50. Время: 51.4044 секунды
# Выполнено 27 из 50. Время: 51.7974 секунды
# Выполнено 28 из 50. Время: 52.1976 секунды
# Выполнено 29 из 50. Время: 52.5974 секунды
# Выполнено 30 из 50. Время: 53.0041 секунды
# Выполнено 31 из 50. Время: 53.4145 секунды
# Выполнено 32 из 50. Время: 53.8302 секунды
# Выполнено 33 из 50. Время: 54.2312 секунды
# Выполнено 34 из 50. Время: 54.635 секунды
# Выполнено 35 из 50. Время: 55.0443 секунды
# Выполнено 36 из 50. Время: 55.4478 секунды
# Выполнено 37 из 50. Время: 55.8636 секунды
# Выполнено 38 из 50. Время: 56.265 секунды
# Выполнено 39 из 50. Время: 56.673 секунды
# Выполнено 40 из 50. Время: 57.0805 секунды
# Выполнено 41 из 50. Время: 57.4969 секунды
# Выполнено 42 из 50. Время: 57.8977 секунды
# Выполнено 43 из 50. Время: 58.3042 секунды
# Выполнено 44 из 50. Время: 58.7131 секунды
# Выполнено 45 из 50. Время: 59.1186 секунды
# Выполнено 46 из 50. Время: 59.5136 секунды
# Выполнено 47 из 50. Время: 59.9338 секунды
# Выполнено 48 из 50. Время: 60.3454 секунды
# Выполнено 49 из 50. Время: 60.7482 секунды
# Выполнено 50 из 50. Время: 61.1593 секунды
# ВЫПОЛНЕНО 3 из 9 СТОЛБЦОВ. Время: 61.1593 секунды
# Выполнено 1 из 50. Время: 61.5646 секунды
# Выполнено 2 из 50. Время: 61.9737 секунды
# Выполнено 3 из 50. Время: 62.3797 секунды
# Выполнено 4 из 50. Время: 62.7811 секунды
# Выполнено 5 из 50. Время: 63.1947 секунды
# Выполнено 6 из 50. Время: 63.6196 секунды
# Выполнено 7 из 50. Время: 64.0362 секунды
# Выполнено 8 из 50. Время: 64.4322 секунды
# Выполнено 9 из 50. Время: 64.8466 секунды
# Выполнено 10 из 50. Время: 65.255 секунды
# Выполнено 11 из 50. Время: 65.6571 секунды
# Выполнено 12 из 50. Время: 66.0641 секунды
# Выполнено 13 из 50. Время: 66.4641 секунды
# Выполнено 14 из 50. Время: 66.8818 секунды
# Выполнено 15 из 50. Время: 67.2886 секунды
# Выполнено 16 из 50. Время: 67.6968 секунды
# Выполнено 17 из 50. Время: 68.0987 секунды
# Выполнено 18 из 50. Время: 68.5132 секунды
# Выполнено 19 из 50. Время: 68.9038 секунды
# Выполнено 20 из 50. Время: 69.3246 секунды
# Выполнено 21 из 50. Время: 69.7296 секунды
# Выполнено 22 из 50. Время: 70.1318 секунды
# Выполнено 23 из 50. Время: 70.5509 секунды
# Выполнено 24 из 50. Время: 70.9575 секунды
# Выполнено 25 из 50. Время: 71.3639 секунды
# Выполнено 26 из 50. Время: 71.7644 секунды
# Выполнено 27 из 50. Время: 72.1824 секунды
# Выполнено 28 из 50. Время: 72.5884 секунды
# Выполнено 29 из 50. Время: 72.9968 секунды
# Выполнено 30 из 50. Время: 73.398 секунды
# Выполнено 31 из 50. Время: 73.8137 секунды
# Выполнено 32 из 50. Время: 74.2197 секунды
# Выполнено 33 из 50. Время: 74.6148 секунды
# Выполнено 34 из 50. Время: 75.0312 секунды
# Выполнено 35 из 50. Время: 75.4306 секунды
# Выполнено 36 из 50. Время: 75.8341 секунды
# Выполнено 37 из 50. Время: 76.2511 секунды
# Выполнено 38 из 50. Время: 76.6633 секунды
# Выполнено 39 из 50. Время: 77.0798 секунды
# Выполнено 40 из 50. Время: 77.4964 секунды
# Выполнено 41 из 50. Время: 77.9037 секунды
# Выполнено 42 из 50. Время: 78.3089 секунды
# Выполнено 43 из 50. Время: 78.7133 секунды
# Выполнено 44 из 50. Время: 79.1154 секунды
# Выполнено 45 из 50. Время: 79.5345 секунды
# Выполнено 46 из 50. Время: 79.939 секунды
# Выполнено 47 из 50. Время: 80.3315 секунды
# Выполнено 48 из 50. Время: 80.7313 секунды
# Выполнено 49 из 50. Время: 81.1666 секунды
# Выполнено 50 из 50. Время: 81.5732 секунды
# ВЫПОЛНЕНО 4 из 9 СТОЛБЦОВ. Время: 81.5732 секунды
# Выполнено 1 из 50. Время: 81.9641 секунды
# Выполнено 2 из 50. Время: 82.3644 секунды
# Выполнено 3 из 50. Время: 82.7657 секунды
# Выполнено 4 из 50. Время: 83.1728 секунды
# Выполнено 5 из 50. Время: 83.5969 секунды
# Выполнено 6 из 50. Время: 83.9979 секунды
# Выполнено 7 из 50. Время: 84.3975 секунды
# Выполнено 8 из 50. Время: 84.8038 секунды
# Выполнено 9 из 50. Время: 85.2102 секунды
# Выполнено 10 из 50. Время: 85.6138 секунды
# Выполнено 11 из 50. Время: 86.0297 секунды
# Выполнено 12 из 50. Время: 86.4342 секунды
# Выполнено 13 из 50. Время: 86.8605 секунды
# Выполнено 14 из 50. Время: 87.2606 секунды
# Выполнено 15 из 50. Время: 87.6647 секунды
# Выполнено 16 из 50. Время: 88.0652 секунды
# Выполнено 17 из 50. Время: 88.473 секунды
# Выполнено 18 из 50. Время: 88.8973 секунды
# Выполнено 19 из 50. Время: 89.295 секунды
# Выполнено 20 из 50. Время: 89.7134 секунды
# Выполнено 21 из 50. Время: 90.1215 секунды
# Выполнено 22 из 50. Время: 90.5147 секунды
# Выполнено 23 из 50. Время: 90.9299 секунды
# Выполнено 24 из 50. Время: 91.3394 секунды
# Выполнено 25 из 50. Время: 91.7498 секунды
# Выполнено 26 из 50. Время: 92.1571 секунды
# Выполнено 27 из 50. Время: 92.5634 секунды
# Выполнено 28 из 50. Время: 92.964 секунды
# Выполнено 29 из 50. Время: 93.3666 секунды
# Выполнено 30 из 50. Время: 93.773 секунды
# Выполнено 31 из 50. Время: 94.1802 секунды
# Выполнено 32 из 50. Время: 94.581 секунды
# Выполнено 33 из 50. Время: 94.9971 секунды
# Выполнено 34 из 50. Время: 95.4041 секунды
# Выполнено 35 из 50. Время: 95.7978 секунды
# Выполнено 36 из 50. Время: 96.212 секунды
# Выполнено 37 из 50. Время: 96.6149 секунды
# Выполнено 38 из 50. Время: 97.0344 секунды
# Выполнено 39 из 50. Время: 97.4389 секунды
# Выполнено 40 из 50. Время: 97.8463 секунды
# Выполнено 41 из 50. Время: 98.2646 секунды
# Выполнено 42 из 50. Время: 98.6656 секунды
# Выполнено 43 из 50. Время: 99.0728 секунды
# Выполнено 44 из 50. Время: 99.4804 секунды
# Выполнено 45 из 50. Время: 99.8964 секунды
# Выполнено 46 из 50. Время: 100.2974 секунды
# Выполнено 47 из 50. Время: 100.7045 секунды
# Выполнено 48 из 50. Время: 101.1047 секунды
# Выполнено 49 из 50. Время: 101.5129 секунды
# Выполнено 50 из 50. Время: 101.9147 секунды
# ВЫПОЛНЕНО 5 из 9 СТОЛБЦОВ. Время: 101.9147 секунды
# Выполнено 1 из 50. Время: 102.3182 секунды
# Выполнено 2 из 50. Время: 102.7147 секунды
# Выполнено 3 из 50. Время: 103.1292 секунды
# Выполнено 4 из 50. Время: 103.5311 секунды
# Выполнено 5 из 50. Время: 103.9341 секунды
# Выполнено 6 из 50. Время: 104.3459 секунды
# Выполнено 7 из 50. Время: 104.7323 секунды
# Выполнено 8 из 50. Время: 105.1313 секунды
# Выполнено 9 из 50. Время: 105.5478 секунды
# Выполнено 10 из 50. Время: 105.956 секунды
# Выполнено 11 из 50. Время: 106.3644 секунды
# Выполнено 12 из 50. Время: 106.7804 секунды
# Выполнено 13 из 50. Время: 107.1652 секунды
# Выполнено 14 из 50. Время: 107.5868 секунды
# Выполнено 15 из 50. Время: 107.981 секунды
# Выполнено 16 из 50. Время: 108.3972 секунды
# Выполнено 17 из 50. Время: 108.7973 секунды
# Выполнено 18 из 50. Время: 109.2028 секунды
# Выполнено 19 из 50. Время: 109.6143 секунды
# Выполнено 20 из 50. Время: 110.0144 секунды
# Выполнено 21 из 50. Время: 110.4165 секунды
# Выполнено 22 из 50. Время: 110.8181 секунды
# Выполнено 23 из 50. Время: 111.2292 секунды
# Выполнено 24 из 50. Время: 111.6317 секунды
# Выполнено 25 из 50. Время: 112.0307 секунды
# Выполнено 26 из 50. Время: 112.4325 секунды
# Выполнено 27 из 50. Время: 112.8407 секунды
# Выполнено 28 из 50. Время: 113.2314 секунды
# Выполнено 29 из 50. Время: 113.6468 секунды
# Выполнено 30 из 50. Время: 114.0322 секунды
# Выполнено 31 из 50. Время: 114.4396 секунды
# Выполнено 32 из 50. Время: 114.8465 секунды
# Выполнено 33 из 50. Время: 115.2709 секунды
# Выполнено 34 из 50. Время: 115.6651 секунды
# Выполнено 35 из 50. Время: 116.0711 секунды
# Выполнено 36 из 50. Время: 116.4814 секунды
# Выполнено 37 из 50. Время: 116.8811 секунды
# Выполнено 38 из 50. Время: 117.3002 секунды
# Выполнено 39 из 50. Время: 117.7012 секунды
# Выполнено 40 из 50. Время: 118.1139 секунды
# Выполнено 41 из 50. Время: 118.5146 секунды
# Выполнено 42 из 50. Время: 118.9146 секунды
# Выполнено 43 из 50. Время: 119.3279 секунды
# Выполнено 44 из 50. Время: 119.7399 секунды
# Выполнено 45 из 50. Время: 120.1465 секунды
# Выполнено 46 из 50. Время: 120.5486 секунды
# Выполнено 47 из 50. Время: 120.948 секунды
# Выполнено 48 из 50. Время: 121.3602 секунды
# Выполнено 49 из 50. Время: 121.7631 секунды
# Выполнено 50 из 50. Время: 122.1804 секунды
# ВЫПОЛНЕНО 6 из 9 СТОЛБЦОВ. Время: 122.1804 секунды
# Выполнено 1 из 50. Время: 122.5822 секунды
# Выполнено 2 из 50. Время: 122.9849 секунды
# Выполнено 3 из 50. Время: 123.3967 секунды
# Выполнено 4 из 50. Время: 123.7968 секунды
# Выполнено 5 из 50. Время: 124.1977 секунды
# Выполнено 6 из 50. Время: 124.6036 секунды
# Выполнено 7 из 50. Время: 125.0017 секунды
# Выполнено 8 из 50. Время: 125.3976 секунды
# Выполнено 9 из 50. Время: 125.8135 секунды
# Выполнено 10 из 50. Время: 126.2156 секунды
# Выполнено 11 из 50. Время: 126.6225 секунды
# Выполнено 12 из 50. Время: 127.0296 секунды
# Выполнено 13 из 50. Время: 127.4276 секунды
# Выполнено 14 из 50. Время: 127.8471 секунды
# Выполнено 15 из 50. Время: 128.2543 секунды
# Выполнено 16 из 50. Время: 128.6482 секунды
# Выполнено 17 из 50. Время: 129.0632 секунды
# Выполнено 18 из 50. Время: 129.4598 секунды
# Выполнено 19 из 50. Время: 129.8693 секунды
# Выполнено 20 из 50. Время: 130.2826 секунды
# Выполнено 21 из 50. Время: 130.6807 секунды
# Выполнено 22 из 50. Время: 131.081 секунды
# Выполнено 23 из 50. Время: 131.5013 секунды
# Выполнено 24 из 50. Время: 131.9072 секунды
# Выполнено 25 из 50. Время: 132.3134 секунды
# Выполнено 26 из 50. Время: 132.715 секунды
# Выполнено 27 из 50. Время: 133.1151 секунды
# Выполнено 28 из 50. Время: 133.5383 секунды
# Выполнено 29 из 50. Время: 133.9307 секунды
# Выполнено 30 из 50. Время: 134.3465 секунды
# Выполнено 31 из 50. Время: 134.7479 секунды
# Выполнено 32 из 50. Время: 135.1534 секунды
# Выполнено 33 из 50. Время: 135.5626 секунды
# Выполнено 34 из 50. Время: 135.9796 секунды
# Выполнено 35 из 50. Время: 136.3811 секунды
# Выполнено 36 из 50. Время: 136.7831 секунды
# Выполнено 37 из 50. Время: 137.1921 секунды
# Выполнено 38 из 50. Время: 137.5969 секунды
# Выполнено 39 из 50. Время: 138.0187 секунды
# Выполнено 40 из 50. Время: 138.4143 секунды
# Выполнено 41 из 50. Время: 138.8389 секунды
# Выполнено 42 из 50. Время: 139.2463 секунды
# Выполнено 43 из 50. Время: 139.6475 секунды
# Выполнено 44 из 50. Время: 140.0517 секунды
# Выполнено 45 из 50. Время: 140.4692 секунды
# Выполнено 46 из 50. Время: 140.8642 секунды
# Выполнено 47 из 50. Время: 141.2814 секунды
# Выполнено 48 из 50. Время: 141.681 секунды
# Выполнено 49 из 50. Время: 142.0842 секунды
# Выполнено 50 из 50. Время: 142.5035 секунды
# ВЫПОЛНЕНО 7 из 9 СТОЛБЦОВ. Время: 142.5035 секунды
# Выполнено 1 из 50. Время: 142.8973 секунды
# Выполнено 2 из 50. Время: 143.313 секунды
# Выполнено 3 из 50. Время: 143.716 секунды
# Выполнено 4 из 50. Время: 144.1231 секунды
# Выполнено 5 из 50. Время: 144.5144 секунды
# Выполнено 6 из 50. Время: 144.9299 секунды
# Выполнено 7 из 50. Время: 145.3182 секунды
# Выполнено 8 из 50. Время: 145.738 секунды
# Выполнено 9 из 50. Время: 146.1307 секунды
# Выполнено 10 из 50. Время: 146.547 секунды
# Выполнено 11 из 50. Время: 146.9477 секунды
# Выполнено 12 из 50. Время: 147.3528 секунды
# Выполнено 13 из 50. Время: 147.7644 секунды
# Выполнено 14 из 50. Время: 148.1643 секунды
# Выполнено 15 из 50. Время: 148.5645 секунды
# Выполнено 16 из 50. Время: 148.969 секунды
# Выполнено 17 из 50. Время: 149.3743 секунды
# Выполнено 18 из 50. Время: 149.7816 секунды
# Выполнено 19 из 50. Время: 150.1812 секунды
# Выполнено 20 из 50. Время: 150.5819 секунды
# Выполнено 21 из 50. Время: 150.9938 секунды
# Выполнено 22 из 50. Время: 151.399 секунды
# Выполнено 23 из 50. Время: 151.8146 секунды
# Выполнено 24 из 50. Время: 152.2303 секунды
# Выполнено 25 из 50. Время: 152.6372 секунды
# Выполнено 26 из 50. Время: 153.0466 секунды
# Выполнено 27 из 50. Время: 153.4583 секунды
# Выполнено 28 из 50. Время: 153.8649 секунды
# Выполнено 29 из 50. Время: 154.2689 секунды
# Выполнено 30 из 50. Время: 154.6782 секунды
# Выполнено 31 из 50. Время: 155.0808 секунды
# Выполнено 32 из 50. Время: 155.4783 секунды
# Выполнено 33 из 50. Время: 155.8841 секунды
# Выполнено 34 из 50. Время: 156.2903 секунды
# Выполнено 35 из 50. Время: 156.6964 секунды
# Выполнено 36 из 50. Время: 157.0974 секунды
# Выполнено 37 из 50. Время: 157.5094 секунды
# Выполнено 38 из 50. Время: 157.9221 секунды
# Выполнено 39 из 50. Время: 158.3142 секунды
# Выполнено 40 из 50. Время: 158.7301 секунды
# Выполнено 41 из 50. Время: 159.1308 секунды
# Выполнено 42 из 50. Время: 159.5373 секунды
# Выполнено 43 из 50. Время: 159.9475 секунды
# Выполнено 44 из 50. Время: 160.3474 секунды
# Выполнено 45 из 50. Время: 160.7519 секунды
# Выполнено 46 из 50. Время: 161.1524 секунды
# Выполнено 47 из 50. Время: 161.5768 секунды
# Выполнено 48 из 50. Время: 161.9808 секунды
# Выполнено 49 из 50. Время: 162.3799 секунды
# Выполнено 50 из 50. Время: 162.7973 секунды
# ВЫПОЛНЕНО 8 из 9 СТОЛБЦОВ. Время: 162.7973 секунды
# Выполнено 1 из 50. Время: 163.2059 секунды
# Выполнено 2 из 50. Время: 163.61 секунды
# Выполнено 3 из 50. Время: 164.015 секунды
# Выполнено 4 из 50. Время: 164.4303 секунды
# Выполнено 5 из 50. Время: 164.8367 секунды
# Выполнено 6 из 50. Время: 165.2345 секунды
# Выполнено 7 из 50. Время: 165.6488 секунды
# Выполнено 8 из 50. Время: 166.0479 секунды
# Выполнено 9 из 50. Время: 166.4518 секунды
# Выполнено 10 из 50. Время: 166.8652 секунды
# Выполнено 11 из 50. Время: 167.2649 секунды
# Выполнено 12 из 50. Время: 167.6647 секунды
# Выполнено 13 из 50. Время: 168.0825 секунды
# Выполнено 14 из 50. Время: 168.4906 секунды
# Выполнено 15 из 50. Время: 168.8808 секунды
# Выполнено 16 из 50. Время: 169.2968 секунды
# Выполнено 17 из 50. Время: 169.6981 секунды
# Выполнено 18 из 50. Время: 170.1047 секунды
# Выполнено 19 из 50. Время: 170.5148 секунды
# Выполнено 20 из 50. Время: 170.9301 секунды
# Выполнено 21 из 50. Время: 171.3311 секунды
# Выполнено 22 из 50. Время: 171.7359 секунды
# Выполнено 23 из 50. Время: 172.1307 секунды
# Выполнено 24 из 50. Время: 172.5473 секунды
# Выполнено 25 из 50. Время: 172.9476 секунды
# Выполнено 26 из 50. Время: 173.3519 секунды
# Выполнено 27 из 50. Время: 173.7661 секунды
# Выполнено 28 из 50. Время: 174.1646 секунды
# Выполнено 29 из 50. Время: 174.5643 секунды
# Выполнено 30 из 50. Время: 174.9655 секунды
# Выполнено 31 из 50. Время: 175.3736 секунды
# Выполнено 32 из 50. Время: 175.7812 секунды
# Выполнено 33 из 50. Время: 176.1968 секунды
# Выполнено 34 из 50. Время: 176.5822 секунды
# Выполнено 35 из 50. Время: 176.9881 секунды
# Выполнено 36 из 50. Время: 177.3968 секунды
# Выполнено 37 из 50. Время: 177.789 секунды
# Выполнено 38 из 50. Время: 178.197 секунды
# Выполнено 39 из 50. Время: 178.6044 секунды
# Выполнено 40 из 50. Время: 178.9978 секунды
# Выполнено 41 из 50. Время: 179.3982 секунды
# Выполнено 42 из 50. Время: 179.8137 секунды
# Выполнено 43 из 50. Время: 180.2354 секунды
# Выполнено 44 из 50. Время: 180.6448 секунды
# Выполнено 45 из 50. Время: 181.0478 секунды
# Выполнено 46 из 50. Время: 181.4477 секунды
# Выполнено 47 из 50. Время: 181.8492 секунды
# Выполнено 48 из 50. Время: 182.2574 секунды
# Выполнено 49 из 50. Время: 182.6471 секунды
# Выполнено 50 из 50. Время: 183.0638 секунды
# ВЫПОЛНЕНО 9 из 9 СТОЛБЦОВ. Время: 183.0638 секунды

# %%
# вычисление среднего значение энергии в полосах пропускания измерительных каналов
left_bounds = [Material(i).k_edge_energy() for i in range(11, 100)]
right_bounds = [val for val in left_bounds]
mean_energy_in_pass_band = (np.array(right_bounds) + np.array(left_bounds)) / 2

# %%
number_of_signals = len(EDGE_METHOD_channels)
fig, ax = plt.subplots(figsize=(10, 10))

ax.plot(range(number_of_signals), SIGNALS[5][20], ls='-', marker='D', lw='0.7', ms=5, color='orange')

# настройки графика
ax.set_xlabel('Энергия, МэВ')
ax.set_ylabel('Сигнал, отн. ед')
ax.tick_params(axis='both')
# ax.set_xscale('log')
# ax.set_yscale('log')
# ax.set_xlim(1e-3, 1e+2)
# ax.set_ylim(1e-15, 1.2)
ax.grid(True)

# %% [markdown]
# Динамический диапазон

# %%
axis1_energy, axis_z = np.meshgrid(beams_energyes, z_numbers)

# %%
axis_channels, axis2_energy = np.meshgrid([i for i in range(first_channel, last_channel+2)], beams_energyes)

# %%
SIGNALS.shape
# Out:
# (9, 50, 91)

# %%
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': '3d'})
ax.plot_surface(axis2_energy, axis_channels, SIGNALS[8,:,:], cmap=cm.Set2, linewidth=0.3, edgecolors='k', shade=True)

ax.set_xlabel('Энергия электронов, МэВ')
ax.set_ylabel('Номер канала')
# ax.set_zlabel('Ср.кв. ошибка восстановления, отн. ед.')
fig.tight_layout()

# ax.xaxis.set_major_formatter(mticker.FuncFormatter(log_tick_formatter))
# ax.xaxis.set_major_locator(mticker.MaxNLocator(integer=True))

# угол зрения (линейный)
# ax.view_init(elev=20, azim=-135)

# угол зрения (логарифм)
ax.view_init(elev=25, azim=55)
fig.tight_layout()
# fig.savefig('Фильтрационные_кривые_К_пропускание_04_z90.jpg', bbox_inches='tight')

# %% [markdown]
# Восстановление спектра

# %%
# создание матрицы задачи
Matrix = np.array([simpson_rule(r, regime='c', function_jumps=[Material(60).k_edge_index()]) for r in EDGE_METHOD_channels])
new_mesh = np.array(simpson_rule(EDGE_METHOD_channels[0], regime='m', function_jumps=[Material(60).k_edge_index()]))

# %%
z_example = 5
en_example = 15

# %%
signals_simpson = SIGNALS[z_example][en_example]
brem = bremsstrahlungs[z_example][en_example]
bound_100_kev = Material(100).k_edge_index()

# %%
result = Gold(Matrix, signals_simpson, -1, ENERGY_MESH, new_mesh, brem, iteration_number=10000, bound=bound_100_kev, journal=False)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.plot(ENERGY_MESH, brem, ls='-', lw='2', ms=5, color='magenta')
ax.plot(new_mesh, result[0], ls='-', lw='2', ms=5, color='blue')


# настройки графика
ax.set_xlabel('Энергия, МэВ', fontsize=12)
ax.set_ylabel('Энергетический спектр, отн. ед', fontsize=12)
ax.tick_params(axis='both', labelsize=12)
# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlim(1e-3, 0.1e0)
# ax.set_ylim(1e-7, 1.2)
ax.grid(True)

# %% [markdown]
# #

# %% [markdown]
# Сохранение результатов

# %%
K_EDGE_METHOD_SIGNALS = np.save('СИГНАЛЫ_К_пропускание_04.npy', SIGNALS)
