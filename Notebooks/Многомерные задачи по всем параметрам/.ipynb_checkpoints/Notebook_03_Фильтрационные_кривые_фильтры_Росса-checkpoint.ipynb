# %%
import sys
import time
import numpy as np
import numba as nb
from matplotlib import rc
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

# %%
PathWindows = r"D:\Учеба\Практика\Диплом\gamma"
LibraryPathWindows = r"D:\Учеба\Практика\Диплом\gamma\SpectrumsMeasurementsLibrary"
LibraryPathLinux = r"/home/danis/work/python_works/gamma"
sys.path.insert(0, LibraryPathWindows)
sys.path.insert(0, PathWindows)
sys.path.insert(0, LibraryPathLinux)

# %%
from GammaRayInteractions.Materials import Material, R
from CrossSectionsLibrary.cross_sections_data import ENERGY_MESH
from MeasurementInstrumentation.measurement_techniques import ideal_transmission_function, \
k_edge_method_transmission_function, ross_method_transmission_function, edges_indices, open_detector
from NumericalMethods.simpson_rule import simpson_rule
from NumericalMethods.unfolding_technique import Gold

import matplotlib.ticker as mticker
from local_scripts import initialization_brem, generate_empty_matrix, complete_empty_matrix, integrate_the_row, get_integral_signals, apply_function_to_matrix

# %%
def log_tick_formatter(val, pos=None):
    return f"$10^{{{int(val)}}}$"

# %%
font_properties = {'family' : 'Arial', 'weight' : 'regular', 'size' : 12}
rc('font', **font_properties)

# %% [markdown]
# Создание энергетических спектров

# %%
linspace1 = np.linspace(0.035, 0.1, 25, dtype=np.float32)
linspace2 = np.geomspace(0.11, 3, 25, dtype=np.float32)

# список энергий пучков электронов
beams_energyes = []
beams_energyes.extend(linspace1)
beams_energyes.extend(linspace2)
beams_energyes = np.array(beams_energyes)

# %%
# зарядовые числа материалов мишеней
z_numbers = np.array([10*i for i in range(1,10)])

# %% [markdown]
# Создание трехмерной матрицы спектров

# %%
# создание матрицы со всеми сгенерированными спектрами
empty_bremsstrahlungs_matrix = generate_empty_matrix(len(z_numbers), len(beams_energyes))
bremsstrahlungs = complete_empty_matrix(empty_bremsstrahlungs_matrix, z_numbers, beams_energyes, initialization_brem)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.plot(ENERGY_MESH, bremsstrahlungs[4][49], ls='-', marker='D', lw='0.7', ms=5, color='orange')

# настройки графика
ax.set_xlabel('Энергия, МэВ')
ax.set_ylabel('Сигнал, отн. ед')
ax.tick_params(axis='both')
# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlim(1e-3, 1.e-1)
# ax.set_ylim(1e-15, 1.2)
ax.grid(True)

# %% [markdown]
# Инициализация измерительных каналов

# %%
first_channel = 11
last_channel = 100 
number_of_channels = last_channel - first_channel + 1

# %%
level = 0.5

# %%
# создание измерительных каналов
ROSS_METHOD_channels = [ross_method_transmission_function(num, num+1, level) for num in range(first_channel, last_channel)]
# создание канала с открытым детектором
channel_with_open_detector = open_detector()
# добавление канала с открытым детектором
ROSS_METHOD_channels.insert(0, channel_with_open_detector)

# %%
K = np.array(ROSS_METHOD_channels)

# %%
number_of_signals = fig, ax = plt.subplots(figsize=(10, 10))
for i in ROSS_METHOD_channels:
    ax.plot(ENERGY_MESH, i, ls='-', lw='0.3', ms=5)

# настройки графика
ax.set_xlabel('Энергия, МэВ')
ax.set_ylabel('Сигнал, отн. ед')
ax.tick_params(axis='both')
# ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(1e-3, 1e-1)
ax.set_ylim(1e-3, 1.2)
ax.grid(True)

# %% [markdown]
# Создание матрицы с результатами измерения каждого спектра

# %%
empty_integral_signals_matrix = generate_empty_matrix(len(z_numbers), len(beams_energyes))

# %%
SIGNALS = apply_function_to_matrix(bremsstrahlungs, get_integral_signals, K)
# Out:
# Выполнено 1 из 50. Время: 0.3833 секунды
# Выполнено 2 из 50. Время: 0.7942 секунды
# Выполнено 3 из 50. Время: 1.1974 секунды
# Выполнено 4 из 50. Время: 1.6133 секунды
# Выполнено 5 из 50. Время: 2.0302 секунды
# Выполнено 6 из 50. Время: 2.4478 секунды
# Выполнено 7 из 50. Время: 2.8754 секунды
# Выполнено 8 из 50. Время: 3.2932 секунды
# Выполнено 9 из 50. Время: 3.7099 секунды
# Выполнено 10 из 50. Время: 4.1261 секунды
# Выполнено 11 из 50. Время: 4.543 секунды
# Выполнено 12 из 50. Время: 4.9597 секунды
# Выполнено 13 из 50. Время: 5.3703 секунды
# Выполнено 14 из 50. Время: 5.7924 секунды
# Выполнено 15 из 50. Время: 6.2175 секунды
# Выполнено 16 из 50. Время: 6.6268 секунды
# Выполнено 17 из 50. Время: 7.1197 секунды
# Выполнено 18 из 50. Время: 7.6046 секунды
# Выполнено 19 из 50. Время: 8.0769 секунды
# Выполнено 20 из 50. Время: 8.4994 секунды
# Выполнено 21 из 50. Время: 8.9594 секунды
# Выполнено 22 из 50. Время: 9.376 секунды
# Выполнено 23 из 50. Время: 9.8375 секунды
# Выполнено 24 из 50. Время: 10.2933 секунды
# Выполнено 25 из 50. Время: 10.7156 секунды
# Выполнено 26 из 50. Время: 11.1314 секунды
# Выполнено 27 из 50. Время: 11.5492 секунды
# Выполнено 28 из 50. Время: 11.9728 секунды
# Выполнено 29 из 50. Время: 12.4043 секунды
# Выполнено 30 из 50. Время: 12.8266 секунды
# Выполнено 31 из 50. Время: 13.2269 секунды
# Выполнено 32 из 50. Время: 13.6493 секунды
# Выполнено 33 из 50. Время: 14.0654 секунды
# Выполнено 34 из 50. Время: 14.4764 секунды
# Выполнено 35 из 50. Время: 14.8837 секунды
# Выполнено 36 из 50. Время: 15.3126 секунды
# Выполнено 37 из 50. Время: 15.7217 секунды
# Выполнено 38 из 50. Время: 16.1647 секунды
# Выполнено 39 из 50. Время: 16.6037 секунды
# Выполнено 40 из 50. Время: 17.0168 секунды
# Выполнено 41 из 50. Время: 17.4504 секунды
# Выполнено 42 из 50. Время: 17.8584 секунды
# Выполнено 43 из 50. Время: 18.2718 секунды
# Выполнено 44 из 50. Время: 18.6846 секунды
# Выполнено 45 из 50. Время: 19.1156 секунды
# Выполнено 46 из 50. Время: 19.5332 секунды
# Выполнено 47 из 50. Время: 19.9431 секунды
# Выполнено 48 из 50. Время: 20.3911 секунды
# Выполнено 49 из 50. Время: 20.8086 секунды
# Выполнено 50 из 50. Время: 21.217 секунды
# ВЫПОЛНЕНО 1 из 9 СТОЛБЦОВ. Время: 21.217 секунды
# Выполнено 1 из 50. Время: 21.6472 секунды
# Выполнено 2 из 50. Время: 22.062 секунды
# Выполнено 3 из 50. Время: 22.5079 секунды
# Выполнено 4 из 50. Время: 22.911 секунды
# Выполнено 5 из 50. Время: 23.3263 секунды
# Выполнено 6 из 50. Время: 23.755 секунды
# Выполнено 7 из 50. Время: 24.1723 секунды
# Выполнено 8 из 50. Время: 24.5681 секунды
# Выполнено 9 из 50. Время: 24.9909 секунды
# Выполнено 10 из 50. Время: 25.4056 секунды
# Выполнено 11 из 50. Время: 25.8573 секунды
# Выполнено 12 из 50. Время: 26.2813 секунды
# Выполнено 13 из 50. Время: 26.6933 секунды
# Выполнено 14 из 50. Время: 27.124 секунды
# Выполнено 15 из 50. Время: 27.5384 секунды
# Выполнено 16 из 50. Время: 27.9492 секунды
# Выполнено 17 из 50. Время: 28.3672 секунды
# Выполнено 18 из 50. Время: 28.8299 секунды
# Выполнено 19 из 50. Время: 29.2579 секунды
# Выполнено 20 из 50. Время: 29.6789 секунды
# Выполнено 21 из 50. Время: 30.1347 секунды
# Выполнено 22 из 50. Время: 30.5504 секунды
# Выполнено 23 из 50. Время: 30.9671 секунды
# Выполнено 24 из 50. Время: 31.3827 секунды
# Выполнено 25 из 50. Время: 31.8156 секунды
# Выполнено 26 из 50. Время: 32.2271 секунды
# Выполнено 27 из 50. Время: 32.628 секунды
# Выполнено 28 из 50. Время: 33.0272 секунды
# Выполнено 29 из 50. Время: 33.4428 секунды
# Выполнено 30 из 50. Время: 33.8878 секунды
# Выполнено 31 из 50. Время: 34.293 секунды
# Выполнено 32 из 50. Время: 34.7102 секунды
# Выполнено 33 из 50. Время: 35.1108 секунды
# Выполнено 34 из 50. Время: 35.5427 секунды
# Выполнено 35 из 50. Время: 35.9684 секунды
# Выполнено 36 из 50. Время: 36.392 секунды
# Выполнено 37 из 50. Время: 36.8099 секунды
# Выполнено 38 из 50. Время: 37.226 секунды
# Выполнено 39 из 50. Время: 37.659 секунды
# Выполнено 40 из 50. Время: 38.0719 секунды
# Выполнено 41 из 50. Время: 38.4761 секунды
# Выполнено 42 из 50. Время: 38.8961 секунды
# Выполнено 43 из 50. Время: 39.3097 секунды
# Выполнено 44 из 50. Время: 39.7103 секунды
# Выполнено 45 из 50. Время: 40.1233 секунды
# Выполнено 46 из 50. Время: 40.5369 секунды
# Выполнено 47 из 50. Время: 40.929 секунды
# Выполнено 48 из 50. Время: 41.3481 секунды
# Выполнено 49 из 50. Время: 41.7442 секунды
# Выполнено 50 из 50. Время: 42.1398 секунды
# ВЫПОЛНЕНО 2 из 9 СТОЛБЦОВ. Время: 42.1398 секунды
# Выполнено 1 из 50. Время: 42.5584 секунды
# Выполнено 2 из 50. Время: 42.9629 секунды
# Выполнено 3 из 50. Время: 43.3789 секунды
# Выполнено 4 из 50. Время: 43.7777 секунды
# Выполнено 5 из 50. Время: 44.1888 секунды
# Выполнено 6 из 50. Время: 44.6089 секунды
# Выполнено 7 из 50. Время: 45.032 секунды
# Выполнено 8 из 50. Время: 45.4274 секунды
# Выполнено 9 из 50. Время: 45.8426 секунды
# Выполнено 10 из 50. Время: 46.263 секунды
# Выполнено 11 из 50. Время: 46.6763 секунды
# Выполнено 12 из 50. Время: 47.1041 секунды
# Выполнено 13 из 50. Время: 47.5291 секунды
# Выполнено 14 из 50. Время: 47.9592 секунды
# Выполнено 15 из 50. Время: 48.3781 секунды
# Выполнено 16 из 50. Время: 48.7961 секунды
# Выполнено 17 из 50. Время: 49.2112 секунды
# Выполнено 18 из 50. Время: 49.6105 секунды
# Выполнено 19 из 50. Время: 50.0247 секунды
# Выполнено 20 из 50. Время: 50.4272 секунды
# Выполнено 21 из 50. Время: 50.8429 секунды
# Выполнено 22 из 50. Время: 51.2564 секунды
# Выполнено 23 из 50. Время: 51.6674 секунды
# Выполнено 24 из 50. Время: 52.0754 секунды
# Выполнено 25 из 50. Время: 52.4619 секунды
# Выполнено 26 из 50. Время: 52.8597 секунды
# Выполнено 27 из 50. Время: 53.2602 секунды
# Выполнено 28 из 50. Время: 53.6456 секунды
# Выполнено 29 из 50. Время: 54.0686 секунды
# Выполнено 30 из 50. Время: 54.4614 секунды
# Выполнено 31 из 50. Время: 54.8665 секунды
# Выполнено 32 из 50. Время: 55.28 секунды
# Выполнено 33 из 50. Время: 55.6823 секунды
# Выполнено 34 из 50. Время: 56.0789 секунды
# Выполнено 35 из 50. Время: 56.5138 секунды
# Выполнено 36 из 50. Время: 56.9258 секунды
# Выполнено 37 из 50. Время: 57.3641 секунды
# Выполнено 38 из 50. Время: 57.7689 секунды
# Выполнено 39 из 50. Время: 58.2009 секунды
# Выполнено 40 из 50. Время: 58.613 секунды
# Выполнено 41 из 50. Время: 59.0558 секунды
# Выполнено 42 из 50. Время: 59.4693 секунды
# Выполнено 43 из 50. Время: 59.8848 секунды
# Выполнено 44 из 50. Время: 60.3047 секунды
# Выполнено 45 из 50. Время: 60.7186 секунды
# Выполнено 46 из 50. Время: 61.1323 секунды
# Выполнено 47 из 50. Время: 61.5447 секунды
# Выполнено 48 из 50. Время: 61.9541 секунды
# Выполнено 49 из 50. Время: 62.3751 секунды
# Выполнено 50 из 50. Время: 62.8014 секунды
# ВЫПОЛНЕНО 3 из 9 СТОЛБЦОВ. Время: 62.8014 секунды
# Выполнено 1 из 50. Время: 63.2135 секунды
# Выполнено 2 из 50. Время: 63.6254 секунды
# Выполнено 3 из 50. Время: 64.0433 секунды
# Выполнено 4 из 50. Время: 64.5409 секунды
# Выполнено 5 из 50. Время: 64.9728 секунды
# Выполнено 6 из 50. Время: 65.3877 секунды
# Выполнено 7 из 50. Время: 65.7954 секунды
# Выполнено 8 из 50. Время: 66.2033 секунды
# Выполнено 9 из 50. Время: 66.6055 секунды
# Выполнено 10 из 50. Время: 66.996 секунды
# Выполнено 11 из 50. Время: 67.4022 секунды
# Выполнено 12 из 50. Время: 67.8083 секунды
# Выполнено 13 из 50. Время: 68.2283 секунды
# Выполнено 14 из 50. Время: 68.6249 секунды
# Выполнено 15 из 50. Время: 69.0467 секунды
# Выполнено 16 из 50. Время: 69.4292 секунды
# Выполнено 17 из 50. Время: 69.8231 секунды
# Выполнено 18 из 50. Время: 70.2405 секунды
# Выполнено 19 из 50. Время: 70.6316 секунды
# Выполнено 20 из 50. Время: 71.0224 секунды
# Выполнено 21 из 50. Время: 71.4129 секунды
# Выполнено 22 из 50. Время: 71.8034 секунды
# Выполнено 23 из 50. Время: 72.2051 секунды
# Выполнено 24 из 50. Время: 72.5956 секунды
# Выполнено 25 из 50. Время: 72.9903 секунды
# Выполнено 26 из 50. Время: 73.3809 секунды
# Выполнено 27 из 50. Время: 73.7711 секунды
# Выполнено 28 из 50. Время: 74.1755 секунды
# Выполнено 29 из 50. Время: 74.5816 секунды
# Выполнено 30 из 50. Время: 74.9669 секунды
# Выполнено 31 из 50. Время: 75.3603 секунды
# Выполнено 32 из 50. Время: 75.7518 секунды
# Выполнено 33 из 50. Время: 76.1593 секунды
# Выполнено 34 из 50. Время: 76.5526 секунды
# Выполнено 35 из 50. Время: 76.9462 секунды
# Выполнено 36 из 50. Время: 77.3367 секунды
# Выполнено 37 из 50. Время: 77.7275 секунды
# Выполнено 38 из 50. Время: 78.1165 секунды
# Выполнено 39 из 50. Время: 78.5096 секунды
# Выполнено 40 из 50. Время: 78.9164 секунды
# Выполнено 41 из 50. Время: 79.3069 секунды
# Выполнено 42 из 50. Время: 79.7017 секунды
# Выполнено 43 из 50. Время: 80.0989 секунды
# Выполнено 44 из 50. Время: 80.4841 секунды
# Выполнено 45 из 50. Время: 80.8901 секунды
# Выполнено 46 из 50. Время: 81.283 секунды
# Выполнено 47 из 50. Время: 81.6735 секунды
# Выполнено 48 из 50. Время: 82.0669 секунды
# Выполнено 49 из 50. Время: 82.4718 секунды
# Выполнено 50 из 50. Время: 82.8665 секунды
# ВЫПОЛНЕНО 4 из 9 СТОЛБЦОВ. Время: 82.8665 секунды
# Выполнено 1 из 50. Время: 83.2672 секунды
# Выполнено 2 из 50. Время: 83.6583 секунды
# Выполнено 3 из 50. Время: 84.0512 секунды
# Выполнено 4 из 50. Время: 84.4422 секунды
# Выполнено 5 из 50. Время: 84.8304 секунды
# Выполнено 6 из 50. Время: 85.2234 секунды
# Выполнено 7 из 50. Время: 85.6171 секунды
# Выполнено 8 из 50. Время: 86.0098 секунды
# Выполнено 9 из 50. Время: 86.3982 секунды
# Выполнено 10 из 50. Время: 86.8044 секунды
# Выполнено 11 из 50. Время: 87.1971 секунды
# Выполнено 12 из 50. Время: 87.5916 секунды
# Выполнено 13 из 50. Время: 87.9847 секунды
# Выполнено 14 из 50. Время: 88.3893 секунды
# Выполнено 15 из 50. Время: 88.7986 секунды
# Выполнено 16 из 50. Время: 89.1946 секунды
# Выполнено 17 из 50. Время: 89.6007 секунды
# Выполнено 18 из 50. Время: 90.0002 секунды
# Выполнено 19 из 50. Время: 90.4022 секунды
# Выполнено 20 из 50. Время: 90.796 секунды
# Выполнено 21 из 50. Время: 91.1916 секунды
# Выполнено 22 из 50. Время: 91.5977 секунды
# Выполнено 23 из 50. Время: 91.9918 секунды
# Выполнено 24 из 50. Время: 92.3965 секунды
# Выполнено 25 из 50. Время: 92.787 секунды
# Выполнено 26 из 50. Время: 93.1932 секунды
# Выполнено 27 из 50. Время: 93.5899 секунды
# Выполнено 28 из 50. Время: 93.977 секунды
# Выполнено 29 из 50. Время: 94.3661 секунды
# Выполнено 30 из 50. Время: 94.7722 секунды
# Выполнено 31 из 50. Время: 95.1497 секунды
# Выполнено 32 из 50. Время: 95.5403 секунды
# Выполнено 33 из 50. Время: 95.9473 секунды
# Выполнено 34 из 50. Время: 96.3491 секунды
# Выполнено 35 из 50. Время: 96.7552 секунды
# Выполнено 36 из 50. Время: 97.1458 секунды
# Выполнено 37 из 50. Время: 97.5363 секунды
# Выполнено 38 из 50. Время: 97.9352 секунды
# Выполнено 39 из 50. Время: 98.3353 секунды
# Выполнено 40 из 50. Время: 98.7257 секунды
# Выполнено 41 из 50. Время: 99.1091 секунды
# Выполнено 42 из 50. Время: 99.5035 секунды
# Выполнено 43 из 50. Время: 99.9019 секунды
# Выполнено 44 из 50. Время: 100.3008 секунды
# Выполнено 45 из 50. Время: 100.699 секунды
# Выполнено 46 из 50. Время: 101.0907 секунды
# Выполнено 47 из 50. Время: 101.4972 секунды
# Выполнено 48 из 50. Время: 101.8877 секунды
# Выполнено 49 из 50. Время: 102.2764 секунды
# Выполнено 50 из 50. Время: 102.6699 секунды
# ВЫПОЛНЕНО 5 из 9 СТОЛБЦОВ. Время: 102.6699 секунды
# Выполнено 1 из 50. Время: 103.0604 секунды
# Выполнено 2 из 50. Время: 103.4604 секунды
# Выполнено 3 из 50. Время: 103.8672 секунды
# Выполнено 4 из 50. Время: 104.2565 секунды
# Выполнено 5 из 50. Время: 104.647 секунды
# Выполнено 6 из 50. Время: 105.0536 секунды
# Выполнено 7 из 50. Время: 105.4502 секунды
# Выполнено 8 из 50. Время: 105.8414 секунды
# Выполнено 9 из 50. Время: 106.2322 секунды
# Выполнено 10 из 50. Время: 106.6426 секунды
# Выполнено 11 из 50. Время: 107.0377 секунды
# Выполнено 12 из 50. Время: 107.4465 секунды
# Выполнено 13 из 50. Время: 107.8449 секунды
# Выполнено 14 из 50. Время: 108.2491 секунды
# Выполнено 15 из 50. Время: 108.6428 секунды
# Выполнено 16 из 50. Время: 109.049 секунды
# Выполнено 17 из 50. Время: 109.4419 секунды
# Выполнено 18 из 50. Время: 109.8481 секунды
# Выполнено 19 из 50. Время: 110.256 секунды
# Выполнено 20 из 50. Время: 110.6504 секунды
# Выполнено 21 из 50. Время: 111.0409 секунды
# Выполнено 22 из 50. Время: 111.4323 секунды
# Выполнено 23 из 50. Время: 111.8413 секунды
# Выполнено 24 из 50. Время: 112.2342 секунды
# Выполнено 25 из 50. Время: 112.6431 секунды
# Выполнено 26 из 50. Время: 113.0331 секунды
# Выполнено 27 из 50. Время: 113.4422 секунды
# Выполнено 28 из 50. Время: 113.8334 секунды
# Выполнено 29 из 50. Время: 114.2295 секунды
# Выполнено 30 из 50. Время: 114.6356 секунды
# Выполнено 31 из 50. Время: 115.0287 секунды
# Выполнено 32 из 50. Время: 115.4193 секунды
# Выполнено 33 из 50. Время: 115.8262 секунды
# Выполнено 34 из 50. Время: 116.2155 секунды
# Выполнено 35 из 50. Время: 116.6119 секунды
# Выполнено 36 из 50. Время: 117.0049 секунды
# Выполнено 37 из 50. Время: 117.3976 секунды
# Выполнено 38 из 50. Время: 117.8037 секунды
# Выполнено 39 из 50. Время: 118.195 секунды
# Выполнено 40 из 50. Время: 118.5927 секунды
# Выполнено 41 из 50. Время: 118.9855 секунды
# Выполнено 42 из 50. Время: 119.379 секунды
# Выполнено 43 из 50. Время: 119.7892 секунды
# Выполнено 44 из 50. Время: 120.1752 секунды
# Выполнено 45 из 50. Время: 120.5795 секунды
# Выполнено 46 из 50. Время: 120.9767 секунды
# Выполнено 47 из 50. Время: 121.3684 секунды
# Выполнено 48 из 50. Время: 121.7589 секунды
# Выполнено 49 из 50. Время: 122.1578 секунды
# Выполнено 50 из 50. Время: 122.5518 секунды
# ВЫПОЛНЕНО 6 из 9 СТОЛБЦОВ. Время: 122.5518 секунды
# Выполнено 1 из 50. Время: 122.9431 секунды
# Выполнено 2 из 50. Время: 123.3373 секунды
# Выполнено 3 из 50. Время: 123.7285 секунды
# Выполнено 4 из 50. Время: 124.1347 секунды
# Выполнено 5 из 50. Время: 124.5265 секунды
# Выполнено 6 из 50. Время: 124.9198 секунды
# Выполнено 7 из 50. Время: 125.3104 секунды
# Выполнено 8 из 50. Время: 125.7197 секунды
# Выполнено 9 из 50. Время: 126.1132 секунды
# Выполнено 10 из 50. Время: 126.5192 секунды
# Выполнено 11 из 50. Время: 126.9125 секунды
# Выполнено 12 из 50. Время: 127.3136 секунды
# Выполнено 13 из 50. Время: 127.7067 секунды
# Выполнено 14 из 50. Время: 128.0973 секунды
# Выполнено 15 из 50. Время: 128.5026 секунды
# Выполнено 16 из 50. Время: 128.8833 секунды
# Выполнено 17 из 50. Время: 129.2895 секунды
# Выполнено 18 из 50. Время: 129.68 секунды
# Выполнено 19 из 50. Время: 130.0738 секунды
# Выполнено 20 из 50. Время: 130.4752 секунды
# Выполнено 21 из 50. Время: 130.8687 секунды
# Выполнено 22 из 50. Время: 131.2749 секунды
# Выполнено 23 из 50. Время: 131.6498 секунды
# Выполнено 24 из 50. Время: 132.064 секунды
# Выполнено 25 из 50. Время: 132.4613 секунды
# Выполнено 26 из 50. Время: 132.8675 секунды
# Выполнено 27 из 50. Время: 133.254 секунды
# Выполнено 28 из 50. Время: 133.6632 секунды
# Выполнено 29 из 50. Время: 134.0537 секунды
# Выполнено 30 из 50. Время: 134.4427 секунды
# Выполнено 31 из 50. Время: 134.8489 секунды
# Выполнено 32 из 50. Время: 135.2394 секунды
# Выполнено 33 из 50. Время: 135.6463 секунды
# Выполнено 34 из 50. Время: 136.0374 секунды
# Выполнено 35 из 50. Время: 136.4266 секунды
# Выполнено 36 из 50. Время: 136.8327 секунды
# Выполнено 37 из 50. Время: 137.2233 секунды
# Выполнено 38 из 50. Время: 137.6138 секунды
# Выполнено 39 из 50. Время: 138.0043 секунды
# Выполнено 40 из 50. Время: 138.4163 секунды
# Выполнено 41 из 50. Время: 138.8103 секунды
# Выполнено 42 из 50. Время: 139.188 секунды
# Выполнено 43 из 50. Время: 139.5965 секунды
# Выполнено 44 из 50. Время: 139.9893 секунды
# Выполнено 45 из 50. Время: 140.378 секунды
# Выполнено 46 из 50. Время: 140.7708 секунды
# Выполнено 47 из 50. Время: 141.1614 секунды
# Выполнено 48 из 50. Время: 141.5546 секунды
# Выполнено 49 из 50. Время: 141.9494 секунды
# Выполнено 50 из 50. Время: 142.3639 секунды
# ВЫПОЛНЕНО 7 из 9 СТОЛБЦОВ. Время: 142.3639 секунды
# Выполнено 1 из 50. Время: 142.7581 секунды
# Выполнено 2 из 50. Время: 143.1702 секунды
# Выполнено 3 из 50. Время: 143.5809 секунды
# Выполнено 4 из 50. Время: 143.968 секунды
# Выполнено 5 из 50. Время: 144.3576 секунды
# Выполнено 6 из 50. Время: 144.7481 секунды
# Выполнено 7 из 50. Время: 145.1542 секунды
# Выполнено 8 из 50. Время: 145.5479 секунды
# Выполнено 9 из 50. Время: 145.9392 секунды
# Выполнено 10 из 50. Время: 146.3364 секунды
# Выполнено 11 из 50. Время: 146.7269 секунды
# Выполнено 12 из 50. Время: 147.1331 секунды
# Выполнено 13 из 50. Время: 147.5392 секунды
# Выполнено 14 из 50. Время: 147.9382 секунды
# Выполнено 15 из 50. Время: 148.3431 секунды
# Выполнено 16 из 50. Время: 148.7334 секунды
# Выполнено 17 из 50. Время: 149.1277 секунды
# Выполнено 18 из 50. Время: 149.521 секунды
# Выполнено 19 из 50. Время: 149.9293 секунды
# Выполнено 20 из 50. Время: 150.3379 секунды
# Выполнено 21 из 50. Время: 150.731 секунды
# Выполнено 22 из 50. Время: 151.1262 секунды
# Выполнено 23 из 50. Время: 151.5205 секунды
# Выполнено 24 из 50. Время: 151.9145 секунды
# Выполнено 25 из 50. Время: 152.3076 секунды
# Выполнено 26 из 50. Время: 152.7137 секунды
# Выполнено 27 из 50. Время: 153.1043 секунды
# Выполнено 28 из 50. Время: 153.4948 секунды
# Выполнено 29 из 50. Время: 153.8888 секунды
# Выполнено 30 из 50. Время: 154.2801 секунды
# Выполнено 31 из 50. Время: 154.6863 секунды
# Выполнено 32 из 50. Время: 155.0924 секунды
# Выполнено 33 из 50. Время: 155.4866 секунды
# Выполнено 34 из 50. Время: 155.8881 секунды
# Выполнено 35 из 50. Время: 156.2928 секунды
# Выполнено 36 из 50. Время: 156.6855 секунды
# Выполнено 37 из 50. Время: 157.0761 секунды
# Выполнено 38 из 50. Время: 157.4849 секунды
# Выполнено 39 из 50. Время: 157.8781 секунды
# Выполнено 40 из 50. Время: 158.2811 секунды
# Выполнено 41 из 50. Время: 158.6934 секунды
# Выполнено 42 из 50. Время: 159.0942 секунды
# Выполнено 43 из 50. Время: 159.48 секунды
# Выполнено 44 из 50. Время: 159.874 секунды
# Выполнено 45 из 50. Время: 160.2902 секунды
# Выполнено 46 из 50. Время: 160.6814 секунды
# Выполнено 47 из 50. Время: 161.0742 секунды
# Выполнено 48 из 50. Время: 161.4804 секунды
# Выполнено 49 из 50. Время: 161.8866 секунды
# Выполнено 50 из 50. Время: 162.2757 секунды
# ВЫПОЛНЕНО 8 из 9 СТОЛБЦОВ. Время: 162.2757 секунды
# Выполнено 1 из 50. Время: 162.6672 секунды
# Выполнено 2 из 50. Время: 163.0734 секунды
# Выполнено 3 из 50. Время: 163.4639 секунды
# Выполнено 4 из 50. Время: 163.8542 секунды
# Выполнено 5 из 50. Время: 164.2769 секунды
# Выполнено 6 из 50. Время: 164.6776 секунды
# Выполнено 7 из 50. Время: 165.0657 секунды
# Выполнено 8 из 50. Время: 165.4626 секунды
# Выполнено 9 из 50. Время: 165.854 секунды
# Выполнено 10 из 50. Время: 166.2694 секунды
# Выполнено 11 из 50. Время: 166.6519 секунды
# Выполнено 12 из 50. Время: 167.058 секунды
# Выполнено 13 из 50. Время: 167.4642 секунды
# Выполнено 14 из 50. Время: 167.8547 секунды
# Выполнено 15 из 50. Время: 168.2638 секунды
# Выполнено 16 из 50. Время: 168.6624 секунды
# Выполнено 17 из 50. Время: 169.0727 секунды
# Выполнено 18 из 50. Время: 169.4822 секунды
# Выполнено 19 из 50. Время: 169.8883 секунды
# Выполнено 20 из 50. Время: 170.2835 секунды
# Выполнено 21 из 50. Время: 170.6849 секунды
# Выполнено 22 из 50. Время: 171.0905 секунды
# Выполнено 23 из 50. Время: 171.4815 секунды
# Выполнено 24 из 50. Время: 171.8673 секунды
# Выполнено 25 из 50. Время: 172.2797 секунды
# Выполнено 26 из 50. Время: 172.6731 секунды
# Выполнено 27 из 50. Время: 173.0551 секунды
# Выполнено 28 из 50. Время: 173.4641 секунды
# Выполнено 29 из 50. Время: 173.8595 секунды
# Выполнено 30 из 50. Время: 174.253 секунды
# Выполнено 31 из 50. Время: 174.6585 секунды
# Выполнено 32 из 50. Время: 175.0539 секунды
# Выполнено 33 из 50. Время: 175.4472 секунды
# Выполнено 34 из 50. Время: 175.8617 секунды
# Выполнено 35 из 50. Время: 176.2562 секунды
# Выполнено 36 из 50. Время: 176.6451 секунды
# Выполнено 37 из 50. Время: 177.054 секунды
# Выполнено 38 из 50. Время: 177.4451 секунды
# Выполнено 39 из 50. Время: 177.8513 секунды
# Выполнено 40 из 50. Время: 178.2418 секунды
# Выполнено 41 из 50. Время: 178.6496 секунды
# Выполнено 42 из 50. Время: 179.0401 секунды
# Выполнено 43 из 50. Время: 179.4307 секунды
# Выполнено 44 из 50. Время: 179.8368 секунды
# Выполнено 45 из 50. Время: 180.2274 секунды
# Выполнено 46 из 50. Время: 180.6328 секунды
# Выполнено 47 из 50. Время: 181.0234 секунды
# Выполнено 48 из 50. Время: 181.4295 секунды
# Выполнено 49 из 50. Время: 181.82 секунды
# Выполнено 50 из 50. Время: 182.2106 секунды
# ВЫПОЛНЕНО 9 из 9 СТОЛБЦОВ. Время: 182.2106 секунды

# %%
# вычисление среднего значение энергии в полосах пропускания измерительных каналов
left_bounds = [Material(i).k_edge_energy() for i in range(11, 100)]
right_bounds = [val for val in left_bounds]
mean_energy_in_pass_band = (np.array(right_bounds) + np.array(left_bounds)) / 2

# %%
number_of_signals = len(ROSS_METHOD_channels)
fig, ax = plt.subplots(figsize=(10, 10))

ax.plot(range(number_of_signals-1), SIGNALS[8][49][1:], ls='-', marker='D', lw='0.7', ms=5, color='orange')

# настройки графика
ax.set_xlabel('Энергия, МэВ')
ax.set_ylabel('Сигнал, отн. ед')
ax.tick_params(axis='both')
# ax.set_xscale('log')
# ax.set_yscale('log')
# ax.set_xlim(1e-3, 1e+2)
# ax.set_ylim(1e-15, 1.2)
ax.grid(True)

# %% [markdown]
# Динамический диапазон

# %%
axis1_energy, axis_z = np.meshgrid(beams_energyes, z_numbers)

# %%
axis_channels, axis2_energy = np.meshgrid([i for i in range(first_channel+1, last_channel+1)], beams_energyes)

# %%
SIGNALS.shape
# Out:
# (9, 50, 90)

# %%
fig, ax = plt.subplots(figsize=(10, 8), subplot_kw={'projection': '3d'})
ax.plot_surface(axis2_energy, axis_channels, SIGNALS[0,:,1:], cmap=cm.Set2, linewidth=0.3, edgecolors='k', shade=True)

ax.set_xlabel('Энергия электронов, МэВ')
ax.set_ylabel('Номер канала')
# ax.set_zlabel('Ср.кв. ошибка восстановления, отн. ед.')
fig.tight_layout()

# ax.xaxis.set_major_formatter(mticker.FuncFormatter(log_tick_formatter))
# ax.xaxis.set_major_locator(mticker.MaxNLocator(integer=True))

# угол зрения (линейный)
# ax.view_init(elev=20, azim=-135)

# угол зрения (логарифм)
ax.view_init(elev=25, azim=55)
fig.tight_layout()
# fig.savefig('Фильтрационные_кривые_Р_пропускание_05_z90.jpg', bbox_inches='tight')

# %% [markdown]
# Восстановление спектра

# %%
# создание матрицы задачи
Matrix = np.array([simpson_rule(r, regime='c', function_jumps=[Material(60).k_edge_index()]) for r in ROSS_METHOD_channels])
new_mesh = np.array(simpson_rule(ROSS_METHOD_channels[0], regime='m', function_jumps=[Material(60).k_edge_index()]))

# %%
z_example = 5
en_example = 15

# %%
signals_simpson = SIGNALS[z_example][en_example]
brem = bremsstrahlungs[z_example][en_example]
bound_100_kev = Material(100).k_edge_index()

# %%
result = Gold(Matrix, signals_simpson, 2, ENERGY_MESH, new_mesh, brem, iteration_number=10000, bound=bound_100_kev, journal=False, weight_mode='channel')

# %%
fig, ax = plt.subplots(figsize=(10, 10))

ax.plot(ENERGY_MESH, brem, ls='-', lw='2', ms=5, color='magenta')
ax.plot(new_mesh, result[0], ls='-', lw='2', ms=5, color='blue')


# настройки графика
ax.set_xlabel('Энергия, МэВ', fontsize=12)
ax.set_ylabel('Энергетический спектр, отн. ед', fontsize=12)
ax.tick_params(axis='both', labelsize=12)
# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlim(1e-3, 0.1e0)
# ax.set_ylim(1e-3, 1.2)
ax.grid(True)

# %% [markdown]
# #

# %% [markdown]
# Сохранение результатов

# %%
# ROSS_METHOD_SIGNALS = np.save('СИГНАЛЫ_Р_пропускание_05.npy', SIGNALS)
