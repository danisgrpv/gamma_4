# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
system = input('windows (w) or linux (l): ')
# Out:
# windows (w) or linux (l): w

# %%
if system == 'w':
    MINDEV_K20 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\K_arrays\K_20_MIN.npy')
    MINDEV_K30 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\K_arrays\K_30_MIN.npy')
    MINDEV_K40 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\K_arrays\K_40_MIN.npy')
    MINDEV_K50 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\K_arrays\K_50_MIN.npy')
    MINDEV_K60 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\K_arrays\K_60_MIN.npy')
    MINDEV_K70 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\K_arrays\K_70_MIN.npy')
    MINDEV_K80 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\K_arrays\K_80_MIN.npy')
    
    MINDEV_R20 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\R_arrays\R_20_MIN.npy')
    MINDEV_R30 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\R_arrays\R_30_MIN.npy')
    MINDEV_R40 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\R_arrays\R_40_MIN.npy')
    MINDEV_R50 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\R_arrays\R_50_MIN.npy')
    MINDEV_R60 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\R_arrays\R_60_MIN.npy')
    MINDEV_R70 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\R_arrays\R_70_MIN.npy')
    MINDEV_R80 = np.load(r'D:\Учеба\Практика\Диплом\gamma_4\arrays\arrays_optimization_problems\R_arrays\R_80_MIN.npy')

# %% [markdown]
# Параметры пучков

# %%
linspace1 = np.linspace(0.035, 0.1, 25, dtype=np.float32)
linspace2 = np.geomspace(0.11, 3, 25, dtype=np.float32)

beams_energyes = []
beams_energyes.extend(linspace1)
beams_energyes.extend(linspace2)

# %% [markdown]
# Уровни пропускания в К-крае

# %%
linspace3 = np.linspace(0.001, 0.9, 51)
for i, val in enumerate(linspace3):
    linspace3[i] = round(val, 5)
    
levels = []
levels.extend(linspace3)

# %% [markdown]
# Зависимость минимальной ошибки восстановления от граничной энерии спектра

# %%
fig, ax = plt.subplots(figsize=(9, 7))

ax.plot(beams_energyes, MINDEV_K20, ls='-', marker='D', lw='0.7', ms=5, label='20')
ax.plot(beams_energyes, MINDEV_K30, ls='-', marker='D', lw='0.7', ms=5, label='30')
ax.plot(beams_energyes, MINDEV_K40, ls='-', marker='D', lw='0.7', ms=5, label='40')
ax.plot(beams_energyes, MINDEV_K50, ls='-', marker='D', lw='0.7', ms=5, label='50')
ax.plot(beams_energyes, MINDEV_K60, ls='-', marker='D', lw='0.7', ms=5, label='60')
ax.plot(beams_energyes, MINDEV_K70, ls='-', marker='D', lw='0.7', ms=5, label='70')
ax.plot(beams_energyes, MINDEV_K80, ls='-', marker='D', lw='0.7', ms=5, label='80')

# настройки графика
ax.set_xlabel('Энергия электронов, МэВ', fontsize=10)
ax.set_ylabel('Минимальное среднеквадратичное отклонение по спектру, отн. ед', fontsize=10)
ax.tick_params(axis='both', labelsize=10)
# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlim(3e-2, 0.14)
ax.set_ylim(0, 0.150)

box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1, box.width, box.height * 0.9])

# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=False, ncol=8)
ax.grid(True)

# fig.savefig('Сравнение минимальной ошибки двух методов 30 Материал до 150 кэВ.jpg', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(9, 7))

ax.plot(beams_energyes, MINDEV_R20, ls='-', marker='D', lw='0.7', ms=5, label='20')
ax.plot(beams_energyes, MINDEV_R30, ls='-', marker='D', lw='0.7', ms=5, label='30')
ax.plot(beams_energyes, MINDEV_R40, ls='-', marker='D', lw='0.7', ms=5, label='40')
ax.plot(beams_energyes, MINDEV_R50, ls='-', marker='D', lw='0.7', ms=5, label='50')
ax.plot(beams_energyes, MINDEV_R60, ls='-', marker='D', lw='0.7', ms=5, label='60')
ax.plot(beams_energyes, MINDEV_R70, ls='-', marker='D', lw='0.7', ms=5, label='70')
ax.plot(beams_energyes, MINDEV_R80, ls='-', marker='D', lw='0.7', ms=5, label='80')

# настройки графика
ax.set_xlabel('Энергия электронов, МэВ', fontsize=10)
ax.set_ylabel('Минимальное среднеквадратичное отклонение по спектру, отн. ед', fontsize=10)
ax.tick_params(axis='both', labelsize=10)
# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_xlim(3e-2, 0.14)
ax.set_ylim(0, 0.150)

box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1, box.width, box.height * 0.9])

# Put a legend below current axis
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), fancybox=True, shadow=False, ncol=8)
ax.grid(True)

# fig.savefig('Сравнение минимальной ошибки двух методов 30 Материал до 150 кэВ.jpg', bbox_inches='tight')

# %%
ROSS = [MINDEV_R20, MINDEV_R30, MINDEV_R40, MINDEV_R50, MINDEV_R60, MINDEV_R70, MINDEV_R80]
KEDGES = [MINDEV_K20, MINDEV_K30, MINDEV_K40, MINDEV_K50, MINDEV_K60, MINDEV_K70, MINDEV_K80]

# %%
from xlsxwriter.workbook import Workbook

workbook = Workbook("Минимальные ошибки восстановления для различных спектров.xlsx")
worksheet = workbook.add_worksheet('Лист1')

left_first_col = 3
space = 3
right_first_col = len(ROSS) + left_first_col + space

worksheet.write_column(5, 0, beams_energyes)

for i,val in enumerate(ROSS):
    worksheet.write_column(5, left_first_col+i, ROSS[i])
    worksheet.write_column(5, right_first_col+i, KEDGES[i])
    
workbook.close()

# %%
# np.savetxt('r30.txt', minimal_deviations_ross30)
# np.savetxt('e30.txt', minimal_deviations_edges30)
# np.savetxt('r50.txt', minimal_deviations_ross50)
# np.savetxt('e50.txt', minimal_deviations_edges50)
# np.savetxt('r80.txt', minimal_deviations_ross80)
# np.savetxt('e80.txt', minimal_deviations_edges80)

# %%
# np.savetxt('beams_energyes.txt', beams_energyes)
